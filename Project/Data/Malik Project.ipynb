# %%
import pandas as pd

# %%
census=pd.read_csv('census_2011.csv')

# %%
census=census[['State name',
'District name',
'Population',
'Male',
'Female',
'Literate',
'Male_Literate',
'Female_Literate',
'Rural_Households',
'Urban_Households',
'Households',
'Age_Group_0_29',
'Age_Group_30_49',
'Age_Group_50',
'Age not stated',
]]

# %%
census1q1=census.copy()

# %%
census1q1
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# ...

# %%
census1q1.rename(columns={'State name': 'State/UT','District name'  : 'District','Male_Literate' : 'Literate_Male','Female_Literate' : 'Literate_Female','Rural_Households' : 'Households_Rural','Urban_ Households' : 'Households_Urban','Age_Group_0_29': 'Young_and_Adult','Age_Group_30_49': 'Middle_Aged','Age_Group_50':'Senior_Citizen','Age not stated': 'Age_Not_Stated',
}, inplace=True)

# %%
census1q1
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
census1q2=census1q1.copy()

# %%
trail=census1q2['State/UT'].copy()

# %%
trail =trail.str.title()

# %%
trail

# %%
trail= trail.str.replace(' And ', ' and ')

# %%
census1q2['State/UT']=trail

# %%
census1q2
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# ## Question 4

# %%
with open ('Telangana.txt', 'r+') as telu:
    tel1=telu.readlines()

# %%
tel1
# Out:
# ['Adilabad\n',
#  'Nizamabad\n',
#  'Karimnagar\n',
#  'Medak\n',
#  'Hyderabad\n',
#  'Rangareddy\n',
#  'Mahbubnagar\n',
#  'Nalgonda\n',
#  'Warangal\n',
#  'Khammam']

# %%
newlist=[]
for i in tel1:
    newlist.append(i.replace('\n',''))
    
    
n

# %%
newlist2=[]
for i in newlist:
    newlist2.append(i.lower())

# %%
census1q2
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
sample=census1q2['District'].copy()

# %%
save=census1q2[sample.isin(newlist)].index

# %%
census1q2.loc[save,'State/UT']='Telangana'

# %%
Laddakh_changing_districts=census1q2[census1q2['District'].isin(['Leh','Kargil'])].index
census1q2.loc[Laddakh_changing_districts,'State/UT']='Laddakh'

# %% [markdown]
# ## Question 5

# %%
census1q5=census1q2.copy()

# %%
old=census1q5.isna().sum()

# %% [markdown]
# percentage of missing columns value

# %%
resultperc=(census1q5.isna().sum()/len(census1q5))*100

# %%
resultperc
# Out:
# State/UT            0.00000
# District            0.00000
# Population          4.68750
# Male                4.68750
# Female              5.15625
# Literate            5.62500
# Literate_Male       4.84375
# Literate_Female     4.21875
# Households_Rural    6.56250
# Urban_Households    5.15625
# Households          5.00000
# Young_and_Adult     4.84375
# Middle_Aged         4.68750
# Senior_Citizen      4.84375
# Age_Not_Stated      5.46875
# dtype: float64

# %%
populationmissingperc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24816\4011789486.py in <module>
# ----> 1 populationmissingperc
#
# NameError: name 'populationmissingperc' is not defined

# %%
list1=census1q5[census1q5['Population'].isna()].index

# %%
list1
# Out:
# Int64Index([  4,  35,  71,  74, 110, 114, 127, 131, 150, 236, 255, 294, 310,
#             320, 342, 367, 419, 427, 458, 460, 475, 479, 484, 497, 516, 517,
#             520, 546, 561, 639],
#            dtype='int64')

# %%
census1q5.loc[list1,'Population'] = census1q5.loc[list1,'Male'] +census1q5.loc[list1,'Female']

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              610 non-null    float64
#  4   Female            607 non-null    float64
#  5   Literate          604 non-null    float64
#  6   Literate_Male     609 non-null    float64
#  7   Literate_Female   613 non-null    float64
#  8   Households_Rural  598 non-null    float64
#  9   Urban_Households  607 non-null    float64
#  10  Households        608 non-null    float64
#  11  Young_and_Adult   609 non-null    float64
#  12  Middle_Aged       610 non-null    float64
#  13  Senior_Citizen    609 non-null    float64
#  14  Age_Not_Stated    605 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
malenan=census1q5[census1q5['Male'].isna()].index

# %%
malenan
# Out:
# Int64Index([  1,   3,  14,  16,  34,  92, 111, 148, 151, 166, 172, 244, 265,
#             336, 366, 373, 383, 387, 413, 466, 478, 480, 482, 505, 512, 531,
#             561, 576, 621, 631],
#            dtype='int64')

# %%
census1q5.loc[malenan,'Male'] = census1q5.loc[malenan,'Population'] - census1q5.loc[malenan,'Female']

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              639 non-null    float64
#  4   Female            607 non-null    float64
#  5   Literate          604 non-null    float64
#  6   Literate_Male     609 non-null    float64
#  7   Literate_Female   613 non-null    float64
#  8   Households_Rural  598 non-null    float64
#  9   Urban_Households  607 non-null    float64
#  10  Households        608 non-null    float64
#  11  Young_and_Adult   609 non-null    float64
#  12  Middle_Aged       610 non-null    float64
#  13  Senior_Citizen    609 non-null    float64
#  14  Age_Not_Stated    605 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
femalenan=census1q5[census1q5['Female'].isna()].index

# %%
census1q5.loc[femalenan,'Female'] = census1q5.loc[femalenan,'Population'] - census1q5.loc[femalenan,'Male']

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              639 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          604 non-null    float64
#  6   Literate_Male     609 non-null    float64
#  7   Literate_Female   613 non-null    float64
#  8   Households_Rural  598 non-null    float64
#  9   Urban_Households  607 non-null    float64
#  10  Households        608 non-null    float64
#  11  Young_and_Adult   609 non-null    float64
#  12  Middle_Aged       610 non-null    float64
#  13  Senior_Citizen    609 non-null    float64
#  14  Age_Not_Stated    605 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
literate=census1q5[census1q5['Literate'].isna()].index
census1q5.loc[literate,'Literate'] = census1q5.loc[literate,'Literate_Male'] + census1q5.loc[literate,'Literate_Female']

# %%
# liteate male

# %%
literatemale=census1q5[census1q5['Literate_Male'].isna()].index
census1q5.loc[literatemale,'Literate_Male'] = census1q5.loc[literatemale,'Literate'] - census1q5.loc[literatemale,'Literate_Female']

# %%
#literate Female

# %%
literatefemale=census1q5[census1q5['Literate_Female'].isna()].index
census1q5.loc[literatefemale,'Literate_Female'] = census1q5.loc[literatefemale,'Literate'] - census1q5.loc[literatefemale,'Literate_Male']

# %%
# Households_Rural

# %%
Households_Rural=census1q5[census1q5['Households_Rural'].isna()].index
census1q5.loc[Households_Rural,'Households_Rural'] = census1q5.loc[Households_Rural,'Households'] - census1q5.loc[Households_Rural,'Urban_Households']

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              639 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          638 non-null    float64
#  6   Literate_Male     638 non-null    float64
#  7   Literate_Female   638 non-null    float64
#  8   Households_Rural  634 non-null    float64
#  9   Urban_Households  607 non-null    float64
#  10  Households        608 non-null    float64
#  11  Young_and_Adult   609 non-null    float64
#  12  Middle_Aged       610 non-null    float64
#  13  Senior_Citizen    609 non-null    float64
#  14  Age_Not_Stated    605 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
Householdsurban=census1q5[census1q5['Urban_Households'].isna()].index
census1q5.loc[Householdsurban,'Urban_Households'] = census1q5.loc[Householdsurban,'Households'] - census1q5.loc[Householdsurban,'Households_Rural']

# %%
#HouseHold values

# %%
Household=census1q5[census1q5['Households'].isna()].index
census1q5.loc[Household,'Households'] = census1q5.loc[Household,'Urban_Households'] + census1q5.loc[Household,'Households_Rural']

# %%
#Population  = Young_and_Adult+  Middle_Aged + Senior_Citizen + Age_Not_Stated

# %%
census1q5['Young_and_Adult'].fillna(census1q5['Population'] - (census1q5['Middle_Aged'] + census1q5['Senior_Citizen'] + census1q5['Age_Not_Stated']), inplace=True)

# %%
census1q5['Middle_Aged'].fillna(census1q5['Population'] - (census1q5['Young_and_Adult'] + census1q5['Senior_Citizen'] + census1q5['Age_Not_Stated']), inplace=True)

# %%
census1q5['Senior_Citizen'].fillna(census1q5['Population'] - (census1q5['Young_and_Adult'] + census1q5['Middle_Aged'] + census1q5['Age_Not_Stated']), inplace=True)

# %%
census1q5['Age_Not_Stated'].fillna(census1q5['Population'] - (census1q5['Young_and_Adult'] + census1q5['Senior_Citizen'] + census1q5['Middle_Aged']), inplace=True)

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              639 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          638 non-null    float64
#  6   Literate_Male     638 non-null    float64
#  7   Literate_Female   638 non-null    float64
#  8   Households_Rural  634 non-null    float64
#  9   Urban_Households  637 non-null    float64
#  10  Households        635 non-null    float64
#  11  Young_and_Adult   636 non-null    float64
#  12  Middle_Aged       634 non-null    float64
#  13  Senior_Citizen    632 non-null    float64
#  14  Age_Not_Stated    637 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
new=census1q5.isna().sum()

# %%
p=pd.DataFrame([old,new]).T
p.columns=['Before Filling','After filling']
p.plot.bar()
# Out:
# <AxesSubplot:>

# %%
census1q5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        639 non-null    float64
#  3   Male              639 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          638 non-null    float64
#  6   Literate_Male     638 non-null    float64
#  7   Literate_Female   638 non-null    float64
#  8   Households_Rural  634 non-null    float64
#  9   Urban_Households  637 non-null    float64
#  10  Households        635 non-null    float64
#  11  Young_and_Adult   636 non-null    float64
#  12  Middle_Aged       634 non-null    float64
#  13  Senior_Citizen    632 non-null    float64
#  14  Age_Not_Stated    637 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
census1q5.to_csv('census1.csv')

# %% [markdown]
# ## Question 7

# %%
cencus=census1q5.copy()

# %%
cencus.head()
# Out:
#             State/UT     District  Population      Male    Female  Literate  \
# 0  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  JAMMU AND KASHMIR       Badgam    753745.0  398041.0  355704.0  335649.0
# 2  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0   54516.0   93770.0
# 3            Laddakh       Kargil    140802.0   77785.0   63017.0   86236.0
# 4  JAMMU AND KASHMIR        Punch    476835.0  251899.0  224936.0  261724.0
#
#    Literate_Male  Literate_Female  Households_Rural  Urban_Households  \
# 0       282823.0         156831.0          158438.0           23226.0
# 1       207741.0         127908.0          160649.0           27190.0
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
# 4       163333.0          98391.0          132139.0           15269.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated
# ...

# %%
housing = pd.read_csv("housing.csv", usecols=['State Name','District Name','Rural/Urban','Total Number of households','Total Number of Livable','Total Number of Dilapidated','Latrine_premise'])

# %%
housing['District Name']=housing['District Name'].str.lower()

# %%
housing.rename(columns={'District Name':'District'},inplace=True)

# %%
housing['State Name']= housing['State Name'].str.replace(' & ', ' and ')

# %%
housing.rename(columns={'State Name':'State/UT'},inplace=True)

# %%
housing['State/UT']=housing['State/UT'].str.lower()

# %%
cencus['State/UT']=cencus['State/UT'].str.lower()

# %%
cencus['District']=cencus['District'].str.lower()

# %%
#Districts present in cencus data but not in housing data 
districts_not_in_housing=[]
h_l=housing['District'].tolist()
for x in cencus['District']:
    if x not in h_l:
        districts_not_in_housing.append(x)
districts_not_in_housing
# Out:
# ['north  and middle andaman']

# %%
housing['District'].replace(['dadra & nagar haveli','puducherry','north  & middle andaman','lahul & spiti'],
                                ['dadra and nagar haveli','pondicherry','north and middle andaman','lahul and spiti'],
                               inplace=True)

# %%
sample=housing['District'].copy()
save=housing[sample.isin(newlist2)].index
housing.loc[save,'State/UT']='telangana'

# %%
save
# Out:
# Int64Index([1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596,
#             1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607,
#             1608, 1609, 1610, 1611, 1612, 1613, 1614],
#            dtype='int64')

# %%
(housing['State/UT']=='telangana').value_counts()
# Out:
# False    1879
# True       29
# Name: State/UT, dtype: int64

# %%
housing_rural=housing[housing['Rural/Urban']=='Rural']
housing_urban=housing[housing['Rural/Urban']=='Urban']
housing_total=housing[housing['Rural/Urban']=='Total']

# %%
merged_urban=cencus.merge(housing_urban,on=['State/UT','District'],how='inner')

# %%
merged_urban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601 entries, 0 to 600
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State/UT                     601 non-null    object
#  1   District                     601 non-null    object
#  2   Population                   600 non-null    float64
#  3   Male                         600 non-null    float64
#  4   Female                       601 non-null    float64
#  5   Literate                     599 non-null    float64
#  6   Literate_Male                599 non-null    float64
#  7   Literate_Female              599 non-null    float64
#  8   Households_Rural             595 non-null    float64
#  9   Urban_Households             598 non-null    float64
#  10  Households                   596 non-null    float64
#  11  Young_and_Adult              598 non-null    float64
# ...

# %%
merged_rural=cencus.merge(housing_rural,on=['State/UT','District'],how='inner')

# %%
merged_rural.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597 entries, 0 to 596
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State/UT                     597 non-null    object
#  1   District                     597 non-null    object
#  2   Population                   596 non-null    float64
#  3   Male                         596 non-null    float64
#  4   Female                       597 non-null    float64
#  5   Literate                     595 non-null    float64
#  6   Literate_Male                595 non-null    float64
#  7   Literate_Female              595 non-null    float64
#  8   Households_Rural             591 non-null    float64
#  9   Urban_Households             594 non-null    float64
#  10  Households                   592 non-null    float64
#  11  Young_and_Adult              594 non-null    float64
# ...

# %%
#caluclating absolute value for Rurals
merged_rural['Households_Rural_Livable']=(merged_rural['Total Number of Livable']/100)*merged_rural['Households_Rural']
merged_rural['Households_Rural_Dilapidated']=(merged_rural['Total Number of Dilapidated']/100)*merged_rural['Households_Rural']
merged_rural['Households_Rural_Toilet_Premise']=(merged_rural['Latrine_premise']/100)*merged_rural['Households_Rural']

# %%
#calculating absolute value for Urbans

merged_urban['Households_Urban_Livable']=(merged_urban['Total Number of Livable']/100)*merged_urban['Urban_Households']
merged_urban['Households_Urban_Dilapidated']=(merged_urban['Total Number of Dilapidated']/100)*merged_urban['Urban_Households']
merged_urban['Households_Urban_Toilet_Premise']=(merged_urban['Latrine_premise']/100)*merged_urban['Urban_Households']

# %%
final_merged=merged_rural.merge(merged_urban,on=['District','State/UT'],how='outer',suffixes=('_Rural', '_Urban'))

# %%
final_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 604 entries, 0 to 603
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   State/UT                           604 non-null    object
#  1   District                           604 non-null    object
#  2   Population_Rural                   596 non-null    float64
#  3   Male_Rural                         596 non-null    float64
#  4   Female_Rural                       597 non-null    float64
#  5   Literate_Rural                     595 non-null    float64
#  6   Literate_Male_Rural                595 non-null    float64
#  7   Literate_Female_Rural              595 non-null    float64
#  8   Households_Rural_Rural             591 non-null    float64
#  9   Urban_Households_Rural             594 non-null    float64
#  10  Households_Rural                   592 non-null    float64
# ...

# %%
# District
# Households_Rural
# Households_Rural_Livable
# Households_Rural_Dilapidated
# Households_Rural_Toilet_Premise
# Households_Urban
# Households_Urban_Livable
# Households_Urban_Dilapidated
# Households_Urban_Toilet_Premise

# %%
final_housing_df=final_merged[
    ['State/UT','District','Households_Rural_Rural','Households_Rural_Livable','Households_Rural_Dilapidated',
     'Households_Rural_Toilet_Premise',
     'Urban_Households_Urban','Households_Urban_Livable',
     'Households_Urban_Dilapidated',
     'Households_Urban_Toilet_Premise']
                              
]

# %%
final_housing_df.head()
# Out:
#             State/UT     District  Households_Rural_Rural  \
# 0  jammu and kashmir      kupwara                158438.0
# 1  jammu and kashmir       badgam                160649.0
# 2  jammu and kashmir  leh(ladakh)                 36920.0
# 3  jammu and kashmir        punch                132139.0
# 4  jammu and kashmir      rajouri                196070.0
#
#    Households_Rural_Livable  Households_Rural_Dilapidated  \
# 0                 92052.478                     13150.354
# 1                 74380.487                      6265.311
# 2                 19013.800                       775.320
# 3                 78622.705                      3171.336
# 4                103721.030                      5293.890
#
#    Households_Rural_Toilet_Premise  Urban_Households_Urban  \
# 0                        77476.182                 23226.0
# 1                       133820.617                 27190.0
# 2                        32526.520                 17474.0
# ...

# %% [markdown]
# ## Question 8

# %% [markdown]
# ## Question 9

# %%
difference=final_housing_df.copy()

# %%
difference["Percent_Difference"]= abs(difference["Households_Rural_Rural"] - difference["Urban_Households_Urban"]) / difference["Households_Rural_Rural"] * 100

# %%
pd.DataFrame(difference[difference["Percent_Difference"] > 10]["District"])
# Out:
#           District
# 0          kupwara
# 1           badgam
# 2      leh(ladakh)
# 3            punch
# 4          rajouri
# ..             ...
# 591     dharmapuri
# 592    krishnagiri
# 593     coimbatore
# 594       tiruppur
# 596  south andaman
#
# [571 rows x 1 columns]

# %%
import pandas as pd

# %% [markdown]
# ## Question 10

# %%
hospital=pd.read_csv("hospitals.csv")

# %%
hospital.head()
# Out:
#                   Unnamed: 0   PHC  CHC   SDH  DH  Hospitals  HospitalBeds
# 0  Andaman & Nicobar Islands    27    4   NaN   3         34          1246
# 1             Andhra Pradesh  1417  198  31.0  20       1666         60799
# 2          Arunachal Pradesh   122   62   NaN  15        199          2320
# 3                      Assam  1007  166  14.0  33       1220         19115
# 4                      Bihar  2007   63  33.0  43       2146         17796

# %%
meta=pd.read_csv('metadata.csv')

# %%
meta
# Out:
#                                    Acronyms
# 0  Number of Primary Health Centers(PHCs),
# 1          Community Health Centers(CHCs),
# 2   Sub-District/Divisional Hospitals(SDHs)
# 3                  District Hospitals(DHs)

# %%
hosp=hospital.copy()

# %%
hosp.rename(columns={'Unnamed: 0':'State/UT','PHC':'Number of Primary Health Centers(PHCs)','CHC':'Community Health Centers(CHCs)','SDH':'Sub-District/Divisional Hospitals(SDHs)','DH':'District Hospitals(DHs)'},inplace=True)

# %%
hosp.head(5)
# Out:
#                     State/UT  Number of Primary Health Centers(PHCs)  \
# 0  Andaman & Nicobar Islands                                      27
# 1             Andhra Pradesh                                    1417
# 2          Arunachal Pradesh                                     122
# 3                      Assam                                    1007
# 4                      Bihar                                    2007
#
#    Community Health Centers(CHCs)  Sub-District/Divisional Hospitals(SDHs)  \
# 0                               4                                      NaN
# 1                             198                                     31.0
# 2                              62                                      NaN
# 3                             166                                     14.0
# 4                              63                                     33.0
#
#    District Hospitals(DHs)  Hospitals  HospitalBeds
# ...
