# %%
import pandas as pd
import numpy as np

# %%
census1=pd.read_csv('census_2011.csv')

# %%
census=census1.copy()

# %%
census=census[['State name','District name','Population',
          'Male','Female','Literate','Male_Literate','Female_Literate','Rural_Households',
         'Urban_Households','Households','Age_Group_0_29','Age_Group_30_49','Age_Group_50','Age not stated']]

# %%
census.rename(columns={'State name':'State/UT', 'District name':'District','Male_Literate':'Literate_Male',
 'Female_Literate':'Literate_Female','Rural_Households ':' Households_Rural',
 'Urban_ Households':'Households_Urban','Age_Group_0_29':' Young_and_Adult',
 'Age_Group_30_49':'Middle_Aged','Age_Group_50':'Senior_Citizen',
 'Age not stated':'Age_Not_Stated'}, inplace=True)

# %%
census['State/UT']=census['State/UT'].replace('Puducherry','PONDICHERRY')
census['State/UT']=census['State/UT'].replace('Odisha','ORISSA')
census['State/UT']=census['State/UT'].replace('Delhi','NCT OF DELHI')

# %%
census['State/UT']=census['State/UT'].str.title()

# %%
census['State/UT']=census['State/UT'].str.replace(' And ', ' and ')

# %%
census[census['State/UT']=='Jammu and Kashmir']
# Out:
#              State/UT     District  Population      Male    Female   Literate  \
# 0   Jammu and Kashmir      Kupwara    870354.0  474190.0  396164.0   439654.0
# 1   Jammu and Kashmir       Badgam    753745.0       NaN  355704.0   335649.0
# 2   Jammu and Kashmir  Leh(Ladakh)    133487.0   78971.0   54516.0    93770.0
# 3   Jammu and Kashmir       Kargil    140802.0       NaN   63017.0        NaN
# 4   Jammu and Kashmir        Punch         NaN  251899.0  224936.0   261724.0
# 5   Jammu and Kashmir      Rajouri    642415.0  345351.0  297064.0   364109.0
# 6   Jammu and Kashmir       Kathua    616435.0  326109.0  290326.0   389204.0
# 7   Jammu and Kashmir     Baramula   1008039.0  534733.0  473306.0        NaN
# 8   Jammu and Kashmir    Bandipore    392232.0  207680.0  184552.0   185979.0
# 9   Jammu and Kashmir     Srinagar   1236829.0  651124.0  585705.0   748584.0
# 10  Jammu and Kashmir    Ganderbal    297446.0  158720.0  138726.0   143276.0
# 11  Jammu and Kashmir      Pulwama    560440.0  293064.0  267376.0   293958.0
# 12  Jammu and Kashmir     Shupiyan    266215.0  136480.0  129735.0   136500.0
# 13  Jammu and Kashmir     Anantnag   1078692.0  559767.0  518925.0        NaN
# 14  Jammu and Kashmir       Kulgam    424483.0       NaN  206863.0   209085.0
# 15  Jammu and Kashmir         Doda    409936.0  213641.0  196295.0   219083.0
# 16  Jammu and Kashmir       Ramban    283713.0       NaN  134581.0   124065.0
# 17  Jammu and Kashmir     Kishtwar    230696.0  120165.0       NaN        NaN
# 18  Jammu and Kashmir     Udhampur    554985.0  296784.0  258201.0   322354.0
# 19  Jammu and Kashmir        Reasi    314667.0  166461.0  148206.0   150542.0
# 20  Jammu and Kashmir        Jammu   1529958.0  813821.0  716137.0  1137135.0
# 21  Jammu and Kashmir        Samba    318898.0  169124.0  149774.0   228139.0
#
#     Literate_Male  Literate_Female  Rural_Households  Urban_Households  \
# 0        282823.0         156831.0          158438.0               NaN
# 1        207741.0         127908.0          160649.0           27190.0
# 2         62834.0          30936.0           36920.0           17474.0
# 3         56301.0          29935.0           40370.0            7774.0
# 4        163333.0          98391.0          132139.0           15269.0
# 5        224469.0         139640.0          196070.0           17508.0
# 6        228499.0         160705.0          181374.0           33473.0
# 7        337170.0         207979.0          210543.0           48932.0
# 8        117058.0          68921.0           80521.0           17555.0
# 9        431746.0         316838.0            4518.0          257721.0
# 10            NaN          52695.0           63788.0           13558.0
# 11       178326.0         115632.0          147520.0           21703.0
# 12        80355.0          56145.0           75616.0            5272.0
# 13       324417.0         221115.0          207067.0           70666.0
# 14       125052.0          84033.0           95952.0           25178.0
# 15       138620.0          80463.0          122267.0           11350.0
# 16        82938.0          41127.0           84281.0               NaN
# 17        68700.0          38806.0           72378.0            5993.0
# 18       197543.0         124811.0          148664.0           34696.0
# 19        93937.0          56605.0           95572.0           12261.0
# 20       641916.0         495219.0          254566.0          248043.0
# 21       130312.0          97827.0           94247.0           19989.0
#
#     Households   Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated
# 0     181664.0          600759.0     178435.0         89679.0          1481.0
# 1     187839.0          503223.0     160933.0         88978.0           611.0
# 2      54394.0           70703.0      41515.0             NaN           250.0
# 3      48144.0           87532.0      35561.0         17488.0           221.0
# 4     147408.0          304979.0     109818.0         61334.0           704.0
# 5     213578.0          404903.0     153165.0         83319.0          1028.0
# 6     214847.0          357864.0     160123.0         97684.0           764.0
# 7     259475.0          636524.0     239659.0        130513.0          1343.0
# 8      98076.0          252378.0          NaN         48802.0           587.0
# 9     262239.0          693238.0     351561.0        190330.0             NaN
# 10     77346.0          194165.0      66945.0         35911.0           425.0
# 11    169223.0          342601.0          NaN             NaN           696.0
# 12     80888.0          170086.0      60752.0         35158.0           219.0
# 13    277733.0          704145.0     239988.0        133519.0          1040.0
# 14    121130.0          266858.0      99870.0         57253.0           502.0
# 15         NaN          263576.0      93189.0         52744.0           427.0
# 16     89622.0          188526.0      61604.0             NaN           363.0
# 17     78371.0               NaN      53415.0         31084.0           266.0
# 18    183360.0          339145.0     140785.0         74757.0           298.0
# 19    107833.0               NaN      70767.0         39743.0           190.0
# 20    502609.0          816827.0     435895.0        275585.0          1651.0
# 21    114236.0          177277.0      88246.0         53022.0           353.0

# %%
with open ('Telangana.txt', 'r+') as telu:
    tel1=telu.readlines()

# %%
finaltellist=[x.replace('\n','') for x in tel1 ]

# %%
finaltellist
# Out:
# ['Adilabad',
#  'Nizamabad',
#  'Karimnagar',
#  'Medak',
#  'Hyderabad',
#  'Rangareddy',
#  'Mahbubnagar',
#  'Nalgonda',
#  'Warangal',
#  'Khammam']

# %%
changing_locs=census[census['District'].isin(finaltellist)].index
census.loc[changing_locs,"State/UT"]='Telangana'

# %%
changing_locs=census[census['District'].isin(['Leh(Ladakh)','Kargil'])].index

census.loc[changing_locs,'State/UT']='Laddakh'

# %%
#question 5

# %%
resultpercold=(census.isna().sum()/len(census))*100

# %%
resultperc
# Out:
# State/UT            0.00000
# District            0.00000
# Population          4.68750
# Male                4.68750
# Female              5.15625
# Literate            5.62500
# Literate_Male       4.84375
# Literate_Female     4.21875
# Rural_Households    6.56250
# Urban_Households    5.15625
# Households          5.00000
#  Young_and_Adult    4.84375
# Middle_Aged         4.68750
# Senior_Citizen      4.84375
# Age_Not_Stated      5.46875
# dtype: float64

# %%
df=census.copy()

# %%
def find_missing_values_indices(x):
    return df[x.isna()].index

# %%
#Filling missing values for Populations columns:
pop_null_ind=df[df['Population'].isna()].index
pop_null_ind

df.loc[pop_null_ind,'Population']=df.loc[pop_null_ind,'Male']+df.loc[pop_null_ind,"Female"]

#Filling missing values for Male
male_null_ind=find_missing_values_indices(df['Male'])
df.loc[male_null_ind,'Male']=df.loc[male_null_ind,'Population']-df.loc[male_null_ind,'Female']

##Filling missing values for Female
female_null_ind=find_missing_values_indices(df['Female'])
df.loc[female_null_ind,'Female']=df.loc[female_null_ind,'Population']-df.loc[female_null_ind,'Male']

# %%
#Filling null values for literate 
lit_null_ind=find_missing_values_indices(df['Literate'])
df.loc[lit_null_ind,'Literate']=df.loc[lit_null_ind,'Literate_Male']+df.loc[lit_null_ind,'Literate_Female']

#Filling null values for Male Literate
lit_male_null_ind=find_missing_values_indices(df['Literate_Male'])
df.loc[lit_male_null_ind,'Literate_Male']=df.loc[lit_male_null_ind,'Literate']-df.loc[lit_male_null_ind,'Literate_Female']

#Filling null values for Female Literate
lit_female_null_ind=find_missing_values_indices(df['Literate_Female'])
df.loc[lit_female_null_ind,'Literate_Female']=df.loc[lit_female_null_ind,'Literate']-df.loc[lit_female_null_ind,'Literate_Male']

# %%
#Filling missing values for Households
household_null_ind=find_missing_values_indices(df['Households'])
df.loc[household_null_ind,'Households']=df.loc[household_null_ind,'Rural_Households']+df.loc[household_null_ind,'Urban_Households']

#Filling missing values for Rural households
r_household_null_ind=find_missing_values_indices(df['Rural_Households'])
df.loc[r_household_null_ind,'Rural_Households']=df.loc[r_household_null_ind,'Households']-df.loc[r_household_null_ind,'Urban_Households']

#Filling missing values for Urban households
u_household_null_ind=find_missing_values_indices(df['Urban_Households'])
df.loc[u_household_null_ind,'Urban_Households']=df.loc[u_household_null_ind,'Households']-df.loc[u_household_null_ind,'Rural_Households']

# %%
#Filling null values for population

pop_null_ind=find_missing_values_indices(df['Population'])


df.loc[pop_null_ind,'Population']=df.loc[pop_null_ind,' Young_and_Adult']+df.loc[pop_null_ind,"Middle_Aged"]+df.loc[pop_null_ind,'Senior_Citizen']
+df.loc[pop_null_ind,'Age_Not_Stated']

yad_null_ind=find_missing_values_indices(df[' Young_and_Adult'])
df.loc[yad_null_ind,' Young_and_Adult']=df.loc[yad_null_ind,'Population']-(df.loc[yad_null_ind,"Middle_Aged"]+df.loc[yad_null_ind,'Senior_Citizen']
+df.loc[yad_null_ind,'Age_Not_Stated'])


mid_null_ind=find_missing_values_indices(df['Middle_Aged'])
df.loc[mid_null_ind,'Middle_Aged']=df.loc[mid_null_ind,'Population']-(df.loc[mid_null_ind," Young_and_Adult"]+df.loc[mid_null_ind,'Senior_Citizen']
+df.loc[mid_null_ind,'Age_Not_Stated'])


not_null_ind=find_missing_values_indices(df['Age_Not_Stated'])
df.loc[not_null_ind,'Age_Not_Stated']=df.loc[not_null_ind,'Population']-(df.loc[not_null_ind," Young_and_Adult"]+df.loc[not_null_ind,'Senior_Citizen']
+df.loc[not_null_ind,'Middle_Aged'])


sen_null_ind=find_missing_values_indices(df['Senior_Citizen'])
df.loc[sen_null_ind,'Senior_Citizen']=df.loc[sen_null_ind,'Population']-(df.loc[sen_null_ind," Young_and_Adult"]+df.loc[sen_null_ind,'Middle_Aged']
+df.loc[sen_null_ind,'Age_Not_Stated'])

# %%
resultpernew=(df.isna().sum()/len(df))*100

# %%
resultpernew
# Out:
# State/UT            0.00000
# District            0.00000
# Population          0.15625
# Male                0.15625
# Female              0.00000
# Literate            0.31250
# Literate_Male       0.31250
# Literate_Female     0.31250
# Rural_Households    0.93750
# Urban_Households    0.46875
# Households          0.78125
#  Young_and_Adult    0.62500
# Middle_Aged         0.93750
# Senior_Citizen      1.25000
# Age_Not_Stated      0.46875
# dtype: float64

# %%
p=pd.DataFrame([resultperc,resultpernew]).T
p.columns=['Before Filling','After filling']
p.plot.bar()
# Out:
# <AxesSubplot:>

# %%
## Question 6

# %%
df.to_csv('Clean_Data/census.csv')

# %%
#question 7

# %%
housing1=pd.read_csv('housing.csv')

# %%
housing=housing1.copy()

# %%
housing=housing[['State Name','District Name','Rural/Urban','Total Number of households','Total Number of Livable','Total Number of Dilapidated','Latrine_premise']]

# %%
housing.rename(columns={'State Name':'State/UT'},inplace=True)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State/UT                     1908 non-null   object
#  1   District Name                1908 non-null   object
#  2   Rural/Urban                  1908 non-null   object
#  3   Total Number of households   1908 non-null   int64
#  4   Total Number of Livable      1908 non-null   float64
#  5   Total Number of Dilapidated  1908 non-null   float64
#  6   Latrine_premise              1908 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 104.5+ KB

# %%
housing['State/UT']=housing['State/UT'].str.lower().str.replace('&','and')

# %%
housing['District Name']=housing['District Name'].str.lower().str.replace('&','and')

# %%
with open ('Telangana.txt', 'r+') as telu:
    tel1=telu.readlines()
finaltellist=[x.replace('\n','') for x in tel1 ]

# %%
finaltellist=[i.lower() for i in finaltellist]

# %%
finaltellist
# Out:
# ['adilabad',
#  'nizamabad',
#  'karimnagar',
#  'medak',
#  'hyderabad',
#  'rangareddy',
#  'mahbubnagar',
#  'nalgonda',
#  'warangal',
#  'khammam']

# %%
housing.head()
# Out:
#             State/UT District Name Rural/Urban  Total Number of households  \
# 0  jammu and kashmir       kupwara       Rural                         100
# 1  jammu and kashmir       kupwara       Total                         100
# 2  jammu and kashmir       kupwara       Urban                         100
# 3  jammu and kashmir        badgam       Rural                         100
# 4  jammu and kashmir        badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
changing_locs=housing[housing['District Name'].isin(finaltellist)].index
housing.loc[changing_locs,"State/UT"]='telangana'

# %%
changing_locs=housing[housing['District Name'].isin(['leh(ladakh)','kargil'])].index

housing.loc[changing_locs,'State/UT']='laddakh'

# %%
housing['State/UT'].replace(['odisha','puducherry'],['orissa','pondicherry'],inplace=True)

# %%
housing[housing['District Name']=='pondicherry']
# Out:
#          State/UT District Name Rural/Urban  Total Number of households  \
# 1892  pondicherry   pondicherry       Rural                         100
# 1893  pondicherry   pondicherry       Total                         100
# 1894  pondicherry   pondicherry       Urban                         100
#
#       Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 1892                     31.9                          2.6             35.8
# 1893                     22.8                          1.6             68.5
# 1894                     19.0                          1.2             82.5

# %%
housing['District Name'].replace(['odisha','puducherry'],['orissa','pondicherry'],inplace=True)

# %%
census1=df.copy()

# %%
census1['State/UT']=census1['State/UT'].str.lower()

# %%
census1['District']=census1['District'].str.lower()

# %%
housing['State/UT']=housing['State/UT'].str.lower().str.replace('&','and')

# %%
#Comparing state names from cencus and housing files
cencus_states=sorted(census1['State/UT'].unique().tolist())
housing_states=sorted(housing['State/UT'].unique().tolist())
l=[]
for i in range(len(cencus_states)):
        if cencus_states[i]!=housing_states[i]:
            l.append((housing_states[i],cencus_states[i]))

# %%
l
# Out:
# []

# %%
districts_not_in_housing=[]
h_l=housing['District Name'].tolist()
for x in census1['District']:
    if x not in h_l:
        districts_not_in_housing.append(x)
districts_not_in_housing
# Out:
# []

# %%
housing_rural=housing[housing['Rural/Urban']=='Rural']
housing_urban=housing[housing['Rural/Urban']=='Urban']
housing_total=housing[housing['Rural/Urban']=='Total']

# %%
merged_rural=census1.merge(housing_rural,left_on=['State/UT','District'],right_on=['State/UT','District Name'],how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11024\149646831.py in <module>
#       1 merged_rural=census1.merge(housing_rural,left_on=['State/UT','District'],right_on=['State/UT','District Name'],how='inner')
# ----> 2 merged_rural[merged_rural['District Name']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['kupwara', 'badgam', 'leh(ladakh)', 'kargil', 'punch', 'rajouri',\n       'kathua', 'baramula', 'bandipore', 'srinagar',\n       ...\n       'kanniyakumari', 'dharmapuri', 'krishnagiri', 'coimbatore', 'tiruppur',\n       'pondicherry', 'karaikal', 'nicobars', 'north  and middle andaman',\n       'south andaman'],\n      dtype='object', length=631)] are in the [columns]"

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11024\1063976557.py in <module>
# ----> 1 merged_rural[merged_rural['District Name']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['kupwara', 'badgam', 'leh(ladakh)', 'kargil', 'punch', 'rajouri',\n       'kathua', 'baramula', 'bandipore', 'srinagar',\n       ...\n       'kanniyakumari', 'dharmapuri', 'krishnagiri', 'coimbatore', 'tiruppur',\n       'pondicherry', 'karaikal', 'nicobars', 'north  and middle andaman',\n       'south andaman'],\n      dtype='object', length=631)] are in the [columns]"

# %%
merged_urban=census1.merge(housing_urban,left_on=['State/UT','District'],right_on=['State/UT','District Name'],how='inner')
merged_urban
# Out:
#                         State/UT                   District  Population  \
# 0              jammu and kashmir                    kupwara    870354.0
# 1              jammu and kashmir                     badgam    753745.0
# 2                        laddakh                leh(ladakh)    133487.0
# 3                        laddakh                     kargil    140802.0
# 4              jammu and kashmir                      punch    476835.0
# ..                           ...                        ...         ...
# 632                  pondicherry                pondicherry    950289.0
# 633                  pondicherry                       mahe     41816.0
# 634                  pondicherry                   karaikal    200222.0
# 635  andaman and nicobar islands  north  and middle andaman    105597.0
# 636  andaman and nicobar islands              south andaman    238142.0
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# 0    474190.0  396164.0  439654.0       282823.0         156831.0
# 1    398041.0  355704.0  335649.0       207741.0         127908.0
# 2     78971.0   54516.0   93770.0        62834.0          30936.0
# 3     77785.0   63017.0   86236.0        56301.0          29935.0
# 4    251899.0  224936.0  261724.0       163333.0          98391.0
# ..        ...       ...       ...            ...              ...
# 632  468258.0  482031.0  726649.0       380946.0         345703.0
# 633   19143.0   22673.0   36470.0        16610.0          19860.0
# 634   97809.0  102413.0  154916.0        79903.0          75013.0
# 635   54861.0   50736.0   78683.0        43186.0          35497.0
# 636  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Rural_Households  Urban_Households  ...   Young_and_Adult  Middle_Aged  \
# 0            158438.0           23226.0  ...          600759.0     178435.0
# 1            160649.0           27190.0  ...          503223.0     160933.0
# 2             36920.0           17474.0  ...           70703.0      41515.0
# 3             40370.0            7774.0  ...           87532.0      35561.0
# 4            132139.0           15269.0  ...          304979.0     109818.0
# ..                ...               ...  ...               ...          ...
# 632           87296.0          203741.0  ...          473705.0     299746.0
# 633               0.0           12110.0  ...           19760.0      12543.0
# 634           35618.0           33715.0  ...               NaN      60089.0
# 635           39091.0            1094.0  ...           57350.0      30741.0
# 636           34901.0           50631.0  ...          128402.0      76332.0
#
#      Senior_Citizen  Age_Not_Stated              District Name Rural/Urban  \
# 0           89679.0          1481.0                    kupwara       Urban
# 1           88978.0           611.0                     badgam       Urban
# 2           21019.0           250.0                leh(ladakh)       Urban
# 3           17488.0           221.0                     kargil       Urban
# 4           61334.0           704.0                      punch       Urban
# ..              ...             ...                        ...         ...
# 632        176204.0           634.0                pondicherry       Urban
# 633          9428.0            85.0                       mahe       Urban
# 634             NaN           366.0                   karaikal       Urban
# 635         17464.0            42.0  north  and middle andaman       Urban
# 636         33128.0           280.0              south andaman       Urban
#
#     Total Number of households  Total Number of Livable  \
# 0                          100                     49.5
# 1                          100                     33.8
# 2                          100                     54.6
# 3                          100                     68.8
# 4                          100                     27.3
# ..                         ...                      ...
# 632                        100                     19.0
# 633                        100                     15.8
# 634                        100                     21.0
# 635                        100                     55.9
# 636                        100                     21.4
#
#      Total Number of Dilapidated  Latrine_premise
# 0                            4.8             70.2
# 1                            2.6             90.4
# 2                            1.1             95.8
# 3                            1.2             97.5
# 4                            0.8             75.3
# ..                           ...              ...
# 632                          1.2             82.5
# 633                          1.1             97.8
# 634                          1.2             74.4
# 635                          6.6             56.1
# 636                          1.2             87.8
#
# [637 rows x 21 columns]

# %%
merged_total=census1.merge(housing_total,left_on=['State/UT','District'],right_on=['State/UT','District Name'],how='inner')
merged_total
# Out:
#                         State/UT                   District  Population  \
# 0              jammu and kashmir                    kupwara    870354.0
# 1              jammu and kashmir                     badgam    753745.0
# 2                        laddakh                leh(ladakh)    133487.0
# 3                        laddakh                     kargil    140802.0
# 4              jammu and kashmir                      punch    476835.0
# ..                           ...                        ...         ...
# 635                  pondicherry                       mahe     41816.0
# 636                  pondicherry                   karaikal    200222.0
# 637  andaman and nicobar islands                   nicobars     36842.0
# 638  andaman and nicobar islands  north  and middle andaman    105597.0
# 639  andaman and nicobar islands              south andaman    238142.0
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# 0    474190.0  396164.0  439654.0       282823.0         156831.0
# 1    398041.0  355704.0  335649.0       207741.0         127908.0
# 2     78971.0   54516.0   93770.0        62834.0          30936.0
# 3     77785.0   63017.0   86236.0        56301.0          29935.0
# 4    251899.0  224936.0  261724.0       163333.0          98391.0
# ..        ...       ...       ...            ...              ...
# 635   19143.0   22673.0   36470.0        16610.0          19860.0
# 636   97809.0  102413.0  154916.0        79903.0          75013.0
# 637   20727.0   16115.0   25332.0        15397.0           9935.0
# 638   54861.0   50736.0   78683.0        43186.0          35497.0
# 639  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Rural_Households  Urban_Households  ...   Young_and_Adult  Middle_Aged  \
# 0            158438.0           23226.0  ...          600759.0     178435.0
# 1            160649.0           27190.0  ...          503223.0     160933.0
# 2             36920.0           17474.0  ...           70703.0      41515.0
# 3             40370.0            7774.0  ...           87532.0      35561.0
# 4            132139.0           15269.0  ...          304979.0     109818.0
# ..                ...               ...  ...               ...          ...
# 635               0.0           12110.0  ...           19760.0      12543.0
# 636           35618.0           33715.0  ...               NaN      60089.0
# 637           15958.0               0.0  ...           18786.0      12088.0
# 638           39091.0            1094.0  ...           57350.0      30741.0
# 639           34901.0           50631.0  ...          128402.0      76332.0
#
#      Senior_Citizen  Age_Not_Stated              District Name Rural/Urban  \
# 0           89679.0          1481.0                    kupwara       Total
# 1           88978.0           611.0                     badgam       Total
# 2           21019.0           250.0                leh(ladakh)       Total
# 3           17488.0           221.0                     kargil       Total
# 4           61334.0           704.0                      punch       Total
# ..              ...             ...                        ...         ...
# 635          9428.0            85.0                       mahe       Total
# 636             NaN           366.0                   karaikal       Total
# 637          5922.0            46.0                   nicobars       Total
# 638         17464.0            42.0  north  and middle andaman       Total
# 639         33128.0           280.0              south andaman       Total
#
#     Total Number of households  Total Number of Livable  \
# 0                          100                     57.3
# 1                          100                     44.7
# 2                          100                     52.4
# 3                          100                     72.6
# 4                          100                     56.9
# ..                         ...                      ...
# 635                        100                     15.8
# 636                        100                     29.2
# 637                        100                     23.8
# 638                        100                     44.6
# 639                        100                     26.4
#
#      Total Number of Dilapidated  Latrine_premise
# 0                            7.9             50.9
# 1                            3.8             84.3
# 2                            1.8             90.4
# 3                            3.2             96.9
# 4                            2.3             18.7
# ..                           ...              ...
# 635                          1.1             97.8
# 636                          1.6             60.6
# 637                          1.2             80.9
# 638                          2.8             48.3
# 639                          2.2             78.3
#
# [640 rows x 21 columns]

# %%
#Calculating absolute values for Rurals
merged_rural['Households_Rural']=merged_rural['Rural_Households']
merged_rural['Households_Rural_Livable']=merged_rural['Rural_Households']*merged_rural['Total Number of Livable']/100
merged_rural['Households_Rural_Dilapidated']=merged_rural['Rural_Households']*merged_rural['Total Number of Dilapidated']/100
merged_rural['Households_Rural_Toilet_Premise']=merged_rural['Rural_Households']*merged_rural['Latrine_premise']/100

# %%
#Calculating absolute values for Urban
merged_urban['Households_Urban']=merged_urban['Urban_Households']
merged_urban['Households_Urban_Livable']=merged_urban['Urban_Households']*merged_urban['Total Number of Livable']/100
merged_urban['Households_Urban_Dilapidated']=merged_urban['Urban_Households']*merged_urban['Total Number of Dilapidated']/100
merged_urban['Households_Urban_Toilet_Premise']=merged_urban['Urban_Households']*merged_urban['Latrine_premise']/100

# %%
merged_urban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 637 entries, 0 to 636
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/UT                         637 non-null    object
#  1   District                         637 non-null    object
#  2   Population                       636 non-null    float64
#  3   Male                             636 non-null    float64
#  4   Female                           637 non-null    float64
#  5   Literate                         635 non-null    float64
#  6   Literate_Male                    635 non-null    float64
#  7   Literate_Female                  635 non-null    float64
#  8   Rural_Households                 631 non-null    float64
#  9   Urban_Households                 634 non-null    float64
#  10  Households                       632 non-null    float64
#  11   Young_and_Adult                 633 non-null    float64
#  12  Middle_Aged                      631 non-null    float64
#  13  Senior_Citizen                   629 non-null    float64
#  14  Age_Not_Stated                   634 non-null    float64
#  15  District Name                    637 non-null    object
#  16  Rural/Urban                      637 non-null    object
#  17  Total Number of households       637 non-null    int64
#  18  Total Number of Livable          637 non-null    float64
#  19  Total Number of Dilapidated      637 non-null    float64
#  20  Latrine_premise                  637 non-null    float64
#  21  Households_Urban                 634 non-null    float64
#  22  Households_Urban_Livable         634 non-null    float64
#  23  Households_Urban_Dilapidated     634 non-null    float64
#  24  Households_Urban_Toilet_Premise  634 non-null    float64
# dtypes: float64(20), int64(1), object(4)
# memory usage: 129.4+ KB

# %%
#Calculating absolute values for total
merged_total['Households_total']=merged_total['Households']
merged_total['Households_total_Livable']=merged_total['Households']*merged_total['Total Number of Livable']/100
merged_total['Households_total_Dilapidated']=merged_total['Households']*merged_total['Total Number of Dilapidated']/100
merged_total['Households_total_Toilet_Premise']=merged_total['Households']*merged_total['Latrine_premise']/100

# %%
final_merged=merged_rural.merge(merged_urban,on=['State/UT','District'],how='outer')
final_merged.head()
# Out:
#             State/UT     District  Population_x    Male_x  Female_x  \
# 0  jammu and kashmir      kupwara      870354.0  474190.0  396164.0
# 1  jammu and kashmir       badgam      753745.0  398041.0  355704.0
# 2            laddakh  leh(ladakh)      133487.0   78971.0   54516.0
# 3            laddakh       kargil      140802.0   77785.0   63017.0
# 4  jammu and kashmir        punch      476835.0  251899.0  224936.0
#
#    Literate_x  Literate_Male_x  Literate_Female_x  Rural_Households_x  \
# 0    439654.0         282823.0           156831.0            158438.0
# 1    335649.0         207741.0           127908.0            160649.0
# 2     93770.0          62834.0            30936.0             36920.0
# 3     86236.0          56301.0            29935.0             40370.0
# 4    261724.0         163333.0            98391.0            132139.0
#
#    Urban_Households_x  ...  District Name_y  Rural/Urban_y  \
# 0             23226.0  ...          kupwara          Urban
# 1             27190.0  ...           badgam          Urban
# 2             17474.0  ...      leh(ladakh)          Urban
# 3              7774.0  ...           kargil          Urban
# 4             15269.0  ...            punch          Urban
#
#    Total Number of households_y  Total Number of Livable_y  \
# 0                         100.0                       49.5
# 1                         100.0                       33.8
# 2                         100.0                       54.6
# 3                         100.0                       68.8
# 4                         100.0                       27.3
#
#    Total Number of Dilapidated_y Latrine_premise_y Households_Urban  \
# 0                            4.8              70.2          23226.0
# 1                            2.6              90.4          27190.0
# 2                            1.1              95.8          17474.0
# 3                            1.2              97.5           7774.0
# 4                            0.8              75.3          15269.0
#
#    Households_Urban_Livable  Households_Urban_Dilapidated  \
# 0                 11496.870                      1114.848
# 1                  9190.220                       706.940
# 2                  9540.804                       192.214
# 3                  5348.512                        93.288
# 4                  4168.437                       122.152
#
#    Households_Urban_Toilet_Premise
# 0                        16304.652
# 1                        24579.760
# 2                        16740.092
# 3                         7579.650
# 4                        11497.557
#
# [5 rows x 48 columns]

# %%
final_merged.rename(columns={'District_x':'District'},inplace=True)
final_merged
# Out:
#               State/UT     District  Population_x    Male_x  Female_x  \
# 0    jammu and kashmir      kupwara      870354.0  474190.0  396164.0
# 1    jammu and kashmir       badgam      753745.0  398041.0  355704.0
# 2              laddakh  leh(ladakh)      133487.0   78971.0   54516.0
# 3              laddakh       kargil      140802.0   77785.0   63017.0
# 4    jammu and kashmir        punch      476835.0  251899.0  224936.0
# ..                 ...          ...           ...       ...       ...
# 635        maharashtra       mumbai           NaN       NaN       NaN
# 636          telangana    hyderabad           NaN       NaN       NaN
# 637         tamil nadu      chennai           NaN       NaN       NaN
# 638        pondicherry        yanam           NaN       NaN       NaN
# 639        pondicherry         mahe           NaN       NaN       NaN
#
#      Literate_x  Literate_Male_x  Literate_Female_x  Rural_Households_x  \
# 0      439654.0         282823.0           156831.0            158438.0
# 1      335649.0         207741.0           127908.0            160649.0
# 2       93770.0          62834.0            30936.0             36920.0
# 3       86236.0          56301.0            29935.0             40370.0
# 4      261724.0         163333.0            98391.0            132139.0
# ..          ...              ...                ...                 ...
# 635         NaN              NaN                NaN                 NaN
# 636         NaN              NaN                NaN                 NaN
# 637         NaN              NaN                NaN                 NaN
# 638         NaN              NaN                NaN                 NaN
# 639         NaN              NaN                NaN                 NaN
#
#      Urban_Households_x  ...  District Name_y  Rural/Urban_y  \
# 0               23226.0  ...          kupwara          Urban
# 1               27190.0  ...           badgam          Urban
# 2               17474.0  ...      leh(ladakh)          Urban
# 3                7774.0  ...           kargil          Urban
# 4               15269.0  ...            punch          Urban
# ..                  ...  ...              ...            ...
# 635                 NaN  ...           mumbai          Urban
# 636                 NaN  ...        hyderabad          Urban
# 637                 NaN  ...          chennai          Urban
# 638                 NaN  ...            yanam          Urban
# 639                 NaN  ...             mahe          Urban
#
#      Total Number of households_y  Total Number of Livable_y  \
# 0                           100.0                       49.5
# 1                           100.0                       33.8
# 2                           100.0                       54.6
# 3                           100.0                       68.8
# 4                           100.0                       27.3
# ..                            ...                        ...
# 635                         100.0                       26.2
# 636                         100.0                       19.1
# 637                         100.0                       17.4
# 638                         100.0                       15.4
# 639                         100.0                       15.8
#
#      Total Number of Dilapidated_y Latrine_premise_y Households_Urban  \
# 0                              4.8              70.2          23226.0
# 1                              2.6              90.4          27190.0
# 2                              1.1              95.8          17474.0
# 3                              1.2              97.5           7774.0
# 4                              0.8              75.3          15269.0
# ..                             ...               ...              ...
# 635                            1.5              67.0        1107321.0
# 636                            0.9              98.5        1066289.0
# 637                            0.9              95.6        1314125.0
# 638                            0.7              81.9          15519.0
# 639                            1.1              97.8          12110.0
#
#      Households_Urban_Livable  Households_Urban_Dilapidated  \
# 0                   11496.870                      1114.848
# 1                    9190.220                       706.940
# 2                    9540.804                       192.214
# 3                    5348.512                        93.288
# 4                    4168.437                       122.152
# ..                        ...                           ...
# 635                290118.102                     16609.815
# 636                203661.199                      9596.601
# 637                228657.750                     11827.125
# 638                  2389.926                       108.633
# 639                  1913.380                       133.210
#
#      Households_Urban_Toilet_Premise
# 0                          16304.652
# 1                          24579.760
# 2                          16740.092
# 3                           7579.650
# 4                          11497.557
# ..                               ...
# 635                       741905.070
# 636                      1050294.665
# 637                      1256303.500
# 638                        12710.061
# 639                        11843.580
#
# [640 rows x 48 columns]

# %%
final_housing_df=final_merged[
    ['State/UT','District','Households_Rural','Households_Rural_Livable','Households_Rural_Dilapidated',
     'Households_Rural_Toilet_Premise',
     'Households_Urban','Households_Urban',
     'Households_Urban_Dilapidated',
     'Households_Urban_Toilet_Premise']
                              
]

# %%
final_housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/UT                         640 non-null    object
#  1   District                         640 non-null    object
#  2   Households_Rural                 625 non-null    float64
#  3   Households_Rural_Livable         625 non-null    float64
#  4   Households_Rural_Dilapidated     625 non-null    float64
#  5   Households_Rural_Toilet_Premise  625 non-null    float64
#  6   Households_Urban                 634 non-null    float64
#  7   Households_Urban                 634 non-null    float64
#  8   Households_Urban_Dilapidated     634 non-null    float64
#  9   Households_Urban_Toilet_Premise  634 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 55.0+ KB

# %%
final_housing_df.isna().sum()
# Out:
# State/UT                            0
# District                            0
# Households_Rural                   15
# Households_Rural_Livable           15
# Households_Rural_Dilapidated       15
# Households_Rural_Toilet_Premise    15
# Households_Urban                    6
# Households_Urban                    6
# Households_Urban_Dilapidated        6
# Households_Urban_Toilet_Premise     6
# dtype: int64

# %%
final_housing_df.to_csv('Clean_Data/censushousing.csv',index=False)

# %%
#Calculating absolute values for total
merged_total['Households_total']=merged_total['Households']
merged_total['Households_total_Livable']=merged_total['Households']*merged_total['Total Number of Livable']/100
merged_total['Households_total_Dilapidated']=merged_total['Households']*merged_total['Total Number of Dilapidated']/100
merged_total['Households_total_Toilet_Premise']=merged_total['Households']*merged_total['Latrine_premise']/100

# %%
merged_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 0 to 639
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/UT                         640 non-null    object
#  1   District                         640 non-null    object
#  2   Population                       639 non-null    float64
#  3   Male                             639 non-null    float64
#  4   Female                           640 non-null    float64
#  5   Literate                         638 non-null    float64
#  6   Literate_Male                    638 non-null    float64
#  7   Literate_Female                  638 non-null    float64
#  8   Rural_Households                 634 non-null    float64
#  9   Urban_Households                 637 non-null    float64
#  10  Households                       635 non-null    float64
#  11   Young_and_Adult                 636 non-null    float64
#  12  Middle_Aged                      634 non-null    float64
#  13  Senior_Citizen                   632 non-null    float64
#  14  Age_Not_Stated                   637 non-null    float64
#  15  District Name                    640 non-null    object
#  16  Rural/Urban                      640 non-null    object
#  17  Total Number of households       640 non-null    int64
#  18  Total Number of Livable          640 non-null    float64
#  19  Total Number of Dilapidated      640 non-null    float64
#  20  Latrine_premise                  640 non-null    float64
#  21  Households_total                 635 non-null    float64
#  22  Households_total_Livable         635 non-null    float64
#  23  Households_total_Dilapidated     635 non-null    float64
#  24  Households_total_Toilet_Premise  635 non-null    float64
#  25  Perc toilet to households        635 non-null    float64
# dtypes: float64(21), int64(1), object(4)
# memory usage: 135.0+ KB

# %%
import matplotlib.pyplot as plt

# %%
# Question 8 part1

# %%
# Question 8 part 2

# %%
merged_total['Households_total_Toilet_Premise']
# Out:
# 0       92466.976
# 1      158348.277
# 2       49172.176
# 3       46651.536
# 4       27565.296
#           ...
# 635     11843.580
# 636     42015.798
# 637     12910.022
# 638     19409.355
# 639     66971.556
# Name: Households_total_Toilet_Premise, Length: 640, dtype: float64

# %%
plt.bar(x=(merged_total['Households_total_Toilet_Premise']/merged_total['Households_total']),height=merged_total['Households_total'])
plt.show()

# %%
merged_total['Perc toilet to households']=(merged_total['Households_total_Toilet_Premise']/merged_total['Total Number of households'])*100

# %%
merged_total['Perc toilet to households']
# Out:
# 0       92466.976
# 1      158348.277
# 2       49172.176
# 3       46651.536
# 4       27565.296
#           ...
# 635     11843.580
# 636     42015.798
# 637     12910.022
# 638     19409.355
# 639     66971.556
# Name: Perc toilet to households, Length: 640, dtype: float64

# %%
# Question 9

# %%
cen=pd.read_csv('Clean_Data/census.csv')

# %%
hou=pd.read_csv('Clean_Data/housing.csv')

# %%
cen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        640 non-null    int64
#  1   State/UT          640 non-null    object
#  2   District          640 non-null    object
#  3   Population        639 non-null    float64
#  4   Male              639 non-null    float64
#  5   Female            640 non-null    float64
#  6   Literate          638 non-null    float64
#  7   Literate_Male     638 non-null    float64
#  8   Literate_Female   638 non-null    float64
#  9   Rural_Households  634 non-null    float64
#  10  Urban_Households  637 non-null    float64
#  11  Households        635 non-null    float64
#  12   Young_and_Adult  636 non-null    float64
#  13  Middle_Aged       634 non-null    float64
#  14  Senior_Citizen    632 non-null    float64
#  15  Age_Not_Stated    637 non-null    float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 80.1+ KB

# %%
hou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/UT                         640 non-null    object
#  1   District                         640 non-null    object
#  2   Households_Rural                 625 non-null    float64
#  3   Households_Rural_Livable         625 non-null    float64
#  4   Households_Rural_Dilapidated     625 non-null    float64
#  5   Households_Rural_Toilet_Premise  625 non-null    float64
#  6   Households_Urban                 634 non-null    float64
#  7   Households_Urban.1               634 non-null    float64
#  8   Households_Urban_Dilapidated     634 non-null    float64
#  9   Households_Urban_Toilet_Premise  634 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 50.1+ KB

# %%
hou.sort_values(by=['State/UT','District'],inplace=True)

# %%
cen.sort_values(by=['State/UT','District'],inplace=True)

# %%
sorted_cencus=cen.groupby(by=['State/UT','District']).sum()
sorted_cencus
# Out:
#                                                         Unnamed: 0  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                           637
#                             North  AND Middle Andaman          638
#                             South Andaman                      639
# Andhra Pradesh              Anantapur                          552
#                             Chittoor                           553
# ...                                                            ...
# West Bengal                 Paschim Medinipur                  343
#                             Purba Medinipur                    344
#                             Puruliya                           339
#                             South Twenty Four Parganas         342
#                             Uttar Dinajpur                     329
#
#                                                         Population       Male  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                       36842.0    20727.0
#                             North  AND Middle Andaman     105597.0    54861.0
#                             South Andaman                 238142.0   127283.0
# Andhra Pradesh              Anantapur                    4081148.0  2064495.0
#                             Chittoor                     4174064.0  2090204.0
# ...                                                            ...        ...
# West Bengal                 Paschim Medinipur            5913457.0  3007885.0
#                             Purba Medinipur              5095875.0  2629834.0
#                             Puruliya                     2930115.0  1496996.0
#                             South Twenty Four Parganas   8161961.0  4173778.0
#                             Uttar Dinajpur               3007134.0  1551066.0
#
#                                                            Female   Literate  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                      16115.0    25332.0
#                             North  AND Middle Andaman     50736.0    78683.0
#                             South Andaman                110859.0   190266.0
# Andhra Pradesh              Anantapur                   2016653.0  2310960.0
#                             Chittoor                    2083860.0  2667878.0
# ...                                                           ...        ...
# West Bengal                 Paschim Medinipur           2905572.0  4078412.0
#                             Purba Medinipur             2466041.0  3923194.0
#                             Puruliya                    1433119.0  1624905.0
#                             South Twenty Four Parganas  3988183.0  5531657.0
#                             Uttar Dinajpur              1456068.0        0.0
#
#                                                         Literate_Male  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                          15397.0
#                             North  AND Middle Andaman         43186.0
#                             South Andaman                    105794.0
# Andhra Pradesh              Anantapur                       1338474.0
#                             Chittoor                        1484794.0
# ...                                                               ...
# West Bengal                 Paschim Medinipur               2266913.0
#                             Purba Medinipur                 2149073.0
#                             Puruliya                        1002058.0
#                             South Twenty Four Parganas      3043277.0
#                             Uttar Dinajpur                   853495.0
#
#                                                         Literate_Female  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                             9935.0
#                             North  AND Middle Andaman           35497.0
#                             South Andaman                       84472.0
# Andhra Pradesh              Anantapur                          972486.0
#                             Chittoor                          1183084.0
# ...                                                                 ...
# West Bengal                 Paschim Medinipur                 1811499.0
#                             Purba Medinipur                   1774121.0
#                             Puruliya                           622847.0
#                             South Twenty Four Parganas        2488380.0
#                             Uttar Dinajpur                          0.0
#
#                                                         Rural_Households  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                             15958.0
#                             North  AND Middle Andaman            39091.0
#                             South Andaman                        34901.0
# Andhra Pradesh              Anantapur                           902997.0
#                             Chittoor                                 0.0
# ...                                                                  ...
# West Bengal                 Paschim Medinipur                  1364335.0
#                             Purba Medinipur                    1193006.0
#                             Puruliya                            653219.0
#                             South Twenty Four Parganas         1568802.0
#                             Uttar Dinajpur                      683981.0
#
#                                                         Urban_Households  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                                 0.0
#                             North  AND Middle Andaman             1094.0
#                             South Andaman                        50631.0
# Andhra Pradesh              Anantapur                           341431.0
#                             Chittoor                            395900.0
# ...                                                                  ...
# West Bengal                 Paschim Medinipur                   201048.0
#                             Purba Medinipur                     170707.0
#                             Puruliya                             99433.0
#                             South Twenty Four Parganas          611430.0
#                             Uttar Dinajpur                       94269.0
#
#                                                         Households  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                       15958.0
#                             North  AND Middle Andaman      40185.0
#                             South Andaman                  85532.0
# Andhra Pradesh              Anantapur                    1244428.0
#                             Chittoor                           0.0
# ...                                                            ...
# West Bengal                 Paschim Medinipur            1565383.0
#                             Purba Medinipur              1363713.0
#                             Puruliya                      752652.0
#                             South Twenty Four Parganas   2180232.0
#                             Uttar Dinajpur                778250.0
#
#                                                          Young_and_Adult  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                             18786.0
#                             North  AND Middle Andaman            57350.0
#                             South Andaman                       128402.0
# Andhra Pradesh              Anantapur                          2189396.0
#                             Chittoor                           2148179.0
# ...                                                                  ...
# West Bengal                 Paschim Medinipur                  3243971.0
#                             Purba Medinipur                    2866678.0
#                             Puruliya                           1678057.0
#                             South Twenty Four Parganas         4763943.0
#                             Uttar Dinajpur                     1916033.0
#
#                                                         Middle_Aged  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                        12088.0
#                             North  AND Middle Andaman       30741.0
#                             South Andaman                   76332.0
# Andhra Pradesh              Anantapur                     1104565.0
#                             Chittoor                      1159053.0
# ...                                                             ...
# West Bengal                 Paschim Medinipur             1664250.0
#                             Purba Medinipur               1384242.0
#                             Puruliya                       764776.0
#                             South Twenty Four Parganas    2151474.0
#                             Uttar Dinajpur                 704859.0
#
#                                                         Senior_Citizen  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                            5922.0
#                             North  AND Middle Andaman          17464.0
#                             South Andaman                      33128.0
# Andhra Pradesh              Anantapur                         739612.0
#                             Chittoor                          807430.0
# ...                                                                ...
# West Bengal                 Paschim Medinipur                 990179.0
#                             Purba Medinipur                   842025.0
#                             Puruliya                          484166.0
#                             South Twenty Four Parganas       1235558.0
#                             Uttar Dinajpur                    385155.0
#
#                                                         Age_Not_Stated
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                              46.0
#                             North  AND Middle Andaman             42.0
#                             South Andaman                        280.0
# Andhra Pradesh              Anantapur                          47575.0
#                             Chittoor                           59402.0
# ...                                                                ...
# West Bengal                 Paschim Medinipur                  15057.0
#                             Purba Medinipur                     2930.0
#                             Puruliya                            3116.0
#                             South Twenty Four Parganas         10986.0
#                             Uttar Dinajpur                      1087.0
#
# [640 rows x 14 columns]

# %%
sorted_housing=hou.groupby(by=['State/UT','District']).sum()
sorted_housing
# Out:
#                                                         Households_Rural  \
# State/UT                    District
# andaman and nicobar islands nicobars                             15958.0
#                             north  and middle andaman            39091.0
#                             south andaman                        34901.0
# andhra pradesh              anantapur                           902997.0
#                             chittoor                                 0.0
# ...                                                                  ...
# west bengal                 paschim medinipur                  1364335.0
#                             purba medinipur                    1193006.0
#                             puruliya                            653219.0
#                             south twenty four parganas         1568802.0
#                             uttar dinajpur                      683981.0
#
#                                                         Households_Rural_Livable  \
# State/UT                    District
# andaman and nicobar islands nicobars                                    3798.004
#                             north  and middle andaman                  17317.313
#                             south andaman                              11691.835
# andhra pradesh              anantapur                                 195950.349
#                             chittoor                                       0.000
# ...                                                                          ...
# west bengal                 paschim medinipur                         712182.870
#                             purba medinipur                           584572.940
#                             puruliya                                  409568.313
#                             south twenty four parganas                782832.198
#                             uttar dinajpur                            396024.999
#
#                                                         Households_Rural_Dilapidated  \
# State/UT                    District
# andaman and nicobar islands nicobars                                         191.496
#                             north  and middle andaman                       1055.457
#                             south andaman                                   1221.535
# andhra pradesh              anantapur                                      26186.913
#                             chittoor                                           0.000
# ...                                                                              ...
# west bengal                 paschim medinipur                             180092.220
#                             purba medinipur                               215934.086
#                             puruliya                                       48338.206
#                             south twenty four parganas                    254145.924
#                             uttar dinajpur                                 84813.644
#
#                                                         Households_Rural_Toilet_Premise  \
# State/UT                    District
# andaman and nicobar islands nicobars                                          12910.022
#                             north  and middle andaman                         18763.680
#                             south andaman                                     22580.947
# andhra pradesh              anantapur                                        198659.340
#                             chittoor                                              0.000
# ...                                                                                 ...
# west bengal                 paschim medinipur                                571656.365
#                             purba medinipur                                 1021213.136
#                             puruliya                                          39846.359
#                             south twenty four parganas                       862841.100
#                             uttar dinajpur                                   140900.086
#
#                                                         Households_Urban  \
# State/UT                    District
# andaman and nicobar islands nicobars                                 0.0
#                             north  and middle andaman             1094.0
#                             south andaman                        50631.0
# andhra pradesh              anantapur                           341431.0
#                             chittoor                            395900.0
# ...                                                                  ...
# west bengal                 paschim medinipur                   201048.0
#                             purba medinipur                     170707.0
#                             puruliya                             99433.0
#                             south twenty four parganas          611430.0
#                             uttar dinajpur                       94269.0
#
#                                                         Households_Urban.1  \
# State/UT                    District
# andaman and nicobar islands nicobars                                   0.0
#                             north  and middle andaman               1094.0
#                             south andaman                          50631.0
# andhra pradesh              anantapur                             341431.0
#                             chittoor                              395900.0
# ...                                                                    ...
# west bengal                 paschim medinipur                     201048.0
#                             purba medinipur                       170707.0
#                             puruliya                               99433.0
#                             south twenty four parganas            611430.0
#                             uttar dinajpur                         94269.0
#
#                                                         Households_Urban_Dilapidated  \
# State/UT                    District
# andaman and nicobar islands nicobars                                           0.000
#                             north  and middle andaman                         72.204
#                             south andaman                                    607.572
# andhra pradesh              anantapur                                       4438.603
#                             chittoor                                        4750.800
# ...                                                                              ...
# west bengal                 paschim medinipur                              16686.984
#                             purba medinipur                                17241.407
#                             puruliya                                        6662.011
#                             south twenty four parganas                     49525.830
#                             uttar dinajpur                                 13763.274
#
#                                                         Households_Urban_Toilet_Premise
# State/UT                    District
# andaman and nicobar islands nicobars                                              0.000
#                             north  and middle andaman                           613.734
#                             south andaman                                     44454.018
# andhra pradesh              anantapur                                        260170.422
#                             chittoor                                         322658.500
# ...                                                                                 ...
# west bengal                 paschim medinipur                                155209.056
#                             purba medinipur                                  141345.396
#                             puruliya                                          50611.397
#                             south twenty four parganas                       508098.330
#                             uttar dinajpur                                    75980.814
#
# [640 rows x 8 columns]

# %%
household_rural_diff=((abs(sorted_housing['Households_Rural']-sorted_cencus['Rural_Households']))/sorted_cencus['Rural_Households'])*100
ind=household_rural_diff[household_rural_diff>10].index

# %%
ind
# Out:
# MultiIndex([], names=['State/UT', 'District'])

# %%
#Question 10

# %%
hospital=pd.read_csv("hospitals.csv")

# %%
meta=pd.read_csv('metadata.csv')

# %%
meta=meta.Acronyms.to_list()

# %%
meta
# Out:
# ['Number of Primary Health Centers(PHCs), ',
#  'Community Health Centers(CHCs), ',
#  'Sub-District/Divisional Hospitals(SDHs)',
#  'District Hospitals(DHs) ']

# %%
kd={}

for val in meta:
    a=val.split('(')
    val=a[0]
    key=a[1].split(')')[0][0:-1]
    kd[key]=val

# %%
kd
# Out:
# {'PHC': 'Number of Primary Health Centers',
#  'CHC': 'Community Health Centers',
#  'SDH': 'Sub-District/Divisional Hospitals',
#  'DH': 'District Hospitals'}

# %%
hospital.rename(columns=kd,inplace=True)
hospital.rename(columns={'Unnamed: 0': 'State/UT'},inplace=True)

# %%
hospital
# Out:
#                        State/UT  Number of Primary Health Centers  \
# 0   andaman and nicobar islands                                27
# 1                andhra pradesh                              1417
# 2             arunachal pradesh                               122
# 3                         assam                              1007
# 4                         bihar                              2007
# 5                    chandigarh                                40
# 6                  chhattisgarh                               813
# 7        dadra and nagar haveli                                 9
# 8                 daman and diu                                 4
# 9                         delhi                               534
# 10                          goa                                31
# 11                      gujarat                              1770
# 12                      haryana                               500
# 13             himachal pradesh                               516
# 14            jammu and kashmir                               702
# 15                    jharkhand                               343
# 16                    karnataka                              2547
# 17                       kerala                               933
# 18                  lakshadweep                                 4
# 19               madhya pradesh                              1420
# 20                  maharashtra                              2638
# 21                      manipur                                87
# 22                    meghalaya                               138
# 23                      mizoram                                65
# 24                     nagaland                               134
# 25                       orissa                              1360
# 26                  pondicherry                                40
# 27                       punjab                               521
# 28                    rajasthan                              2463
# 29                       sikkim                                25
# 30                   tamil nadu                              1854
# 31                    telangana                               788
# 32                      tripura                               114
# 33                uttar pradesh                              3277
# 34                  uttarakhand                               275
# 35                  west bengal                              1374
# 36                    all india                             29899
#
#     Community Health Centers  Sub-District/Divisional Hospitals  \
# 0                          4                                NaN
# 1                        198                               31.0
# 2                         62                                NaN
# 3                        166                               14.0
# 4                         63                               33.0
# 5                          2                                1.0
# 6                        166                               12.0
# 7                          2                                1.0
# 8                          2                                NaN
# 9                         25                                9.0
# 10                         4                                2.0
# 11                       385                               44.0
# 12                       131                               24.0
# 13                        79                               61.0
# 14                        87                                NaN
# 15                       179                               13.0
# 16                       207                              147.0
# 17                       229                               82.0
# 18                         3                                2.0
# 19                       324                               72.0
# 20                       430                              101.0
# 21                        17                                1.0
# 22                        29                                NaN
# 23                        10                                3.0
# 24                        21                                NaN
# 25                       377                               27.0
# 26                         4                                5.0
# 27                       146                               47.0
# 28                       579                               64.0
# 29                         2                                1.0
# 30                       385                              310.0
# 31                        82                               47.0
# 32                        22                               12.0
# 33                       671                                NaN
# 34                        69                               19.0
# 35                       406                               70.0
# 36                      5568                             1255.0
#
#     District Hospitals  Hospitals  HospitalBeds
# 0                    3         34          1246
# 1                   20       1666         60799
# 2                   15        199          2320
# 3                   33       1220         19115
# 4                   43       2146         17796
# 5                    4         47          3756
# 6                   32       1023         14354
# 7                    1         13           568
# 8                    2          8           298
# 9                   47        615         20572
# 10                   3         40          2666
# 11                  37       2236         41129
# 12                  28        683         13841
# 13                  15        671          8706
# 14                  29        818         11342
# 15                  23        558          7404
# 16                  42       2943         56333
# 17                  53       1297         39511
# 18                   1         10           250
# 19                  51       1867         38140
# 20                  70       3239         68998
# 21                   9        114          2562
# 22                  13        180          4585
# 23                   9         87          2312
# 24                  11        166          1944
# 25                  35       1799         16497
# 26                   4         53          4462
# 27                  28        742         13527
# 28                  33       3139         51844
# 29                   4         32          1145
# 30                  32       2581         72616
# 31                  15        932         17358
# 32                   9        157          4895
# 33                 174       4122         58310
# 34                  20        383          6660
# 35                  55       1905         51163
# 36                1003      37725        739024

# %%
def filter_State_func(my_df):
    my_df["State/UT"]=my_df["State/UT"].str.lower()
    my_df["State/UT"]=my_df["State/UT"].str.replace("&","and")
    my_df["State/UT"]=my_df["State/UT"].str.replace("puducherry","pondicherry")
    my_df["State/UT"]=my_df["State/UT"].str.replace("*","")
    my_df["State/UT"]=my_df["State/UT"].str.replace("nct of delhi","delhi")
    my_df["State/UT"]=my_df["State/UT"].str.replace("puducherry","pondicherry")
    my_df["State/UT"]=my_df["State/UT"].str.replace("odisha","orissa")
    
    return my_df

# %%
hospital.to_csv('Clean_Data/all_hospitals.csv')

# %%
#Question 11

# %%
cen=pd.read_csv('Clean_Data/census.csv', usecols=['State/UT','Population'])

# %%
cen=filter_State_func(cen)
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3746379972.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   my_df["State/UT"]=my_df["State/UT"].str.replace("*","")

# %%
cen=cen.groupby('State/UT').sum()

# %%
cen=cen.reset_index()

# %%
cen
# Out:
#                        State/UT   Population
# 0   andaman and nicobar islands     380581.0
# 1                andhra pradesh   49386799.0
# 2             arunachal pradesh    1383727.0
# 3                         assam   31205576.0
# 4                         bihar  104099452.0
# 5                    chandigarh    1055450.0
# 6                  chhattisgarh   25545198.0
# 7        dadra and nagar haveli     343709.0
# 8                 daman and diu     243247.0
# 9                         delhi   16787941.0
# 10                          goa    1458545.0
# 11                      gujarat   60439692.0
# 12                      haryana   25351462.0
# 13             himachal pradesh    6864602.0
# 14            jammu and kashmir   12267013.0
# 15                    jharkhand   32988134.0
# 16                    karnataka   59248274.0
# 17                       kerala   33406061.0
# 18                      laddakh     274289.0
# 19                  lakshadweep      64473.0
# 20               madhya pradesh   72626809.0
# 21                  maharashtra  112374333.0
# 22                      manipur    2855794.0
# 23                    meghalaya    2966889.0
# 24                      mizoram    1097206.0
# 25                     nagaland    1978502.0
# 26                       orissa   41974218.0
# 27                  pondicherry    1247953.0
# 28                       punjab   27743338.0
# 29                    rajasthan   68548437.0
# 30                       sikkim     610577.0
# 31                   tamil nadu   72147030.0
# 32                    telangana   35193978.0
# 33                      tripura    3673917.0
# 34                uttar pradesh  199812341.0
# 35                  uttarakhand   10086292.0
# 36                  west bengal   91276115.0

# %%
hospital=filter_State_func(hospital)
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3746379972.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   my_df["State/UT"]=my_df["State/UT"].str.replace("*","")

# %%
hospital
# Out:
# 0     Andaman & Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7          Dadra & Nagar Haveli
# 8                   Daman & Diu
# 9                         Delhi
# 10                          Goa
# 11                      Gujarat
# 12                      Haryana
# 13             Himachal Pradesh
# 14              Jammu & Kashmir
# 15                    Jharkhand
# 16                    Karnataka
# 17                       Kerala
# 18                  Lakshadweep
# 19               Madhya Pradesh
# 20                  Maharashtra
# 21                      Manipur
# 22                    Meghalaya
# 23                      Mizoram
# 24                     Nagaland
# 25                       Odisha
# 26                   Puducherry
# 27                       Punjab
# 28                    Rajasthan
# 29                       Sikkim
# 30                   Tamil Nadu
# 31                    Telangana
# 32                      Tripura
# 33                Uttar Pradesh
# 34                  Uttarakhand
# 35                  West Bengal
# 36                    All India
# Name: State/UT, dtype: object

# %%
hospcen=hospital.merge(cen, on='State/UT', how='left')

# %%
hospcen
# Out:
#                        State/UT  Number of Primary Health Centers  \
# 0   andaman and nicobar islands                                27
# 1                andhra pradesh                              1417
# 2             arunachal pradesh                               122
# 3                         assam                              1007
# 4                         bihar                              2007
# 5                    chandigarh                                40
# 6                  chhattisgarh                               813
# 7        dadra and nagar haveli                                 9
# 8                 daman and diu                                 4
# 9                         delhi                               534
# 10                          goa                                31
# 11                      gujarat                              1770
# 12                      haryana                               500
# 13             himachal pradesh                               516
# 14            jammu and kashmir                               702
# 15                    jharkhand                               343
# 16                    karnataka                              2547
# 17                       kerala                               933
# 18                  lakshadweep                                 4
# 19               madhya pradesh                              1420
# 20                  maharashtra                              2638
# 21                      manipur                                87
# 22                    meghalaya                               138
# 23                      mizoram                                65
# 24                     nagaland                               134
# 25                       orissa                              1360
# 26                  pondicherry                                40
# 27                       punjab                               521
# 28                    rajasthan                              2463
# 29                       sikkim                                25
# 30                   tamil nadu                              1854
# 31                    telangana                               788
# 32                      tripura                               114
# 33                uttar pradesh                              3277
# 34                  uttarakhand                               275
# 35                  west bengal                              1374
# 36                    all india                             29899
#
#     Community Health Centers  Sub-District/Divisional Hospitals  \
# 0                          4                                NaN
# 1                        198                               31.0
# 2                         62                                NaN
# 3                        166                               14.0
# 4                         63                               33.0
# 5                          2                                1.0
# 6                        166                               12.0
# 7                          2                                1.0
# 8                          2                                NaN
# 9                         25                                9.0
# 10                         4                                2.0
# 11                       385                               44.0
# 12                       131                               24.0
# 13                        79                               61.0
# 14                        87                                NaN
# 15                       179                               13.0
# 16                       207                              147.0
# 17                       229                               82.0
# 18                         3                                2.0
# 19                       324                               72.0
# 20                       430                              101.0
# 21                        17                                1.0
# 22                        29                                NaN
# 23                        10                                3.0
# 24                        21                                NaN
# 25                       377                               27.0
# 26                         4                                5.0
# 27                       146                               47.0
# 28                       579                               64.0
# 29                         2                                1.0
# 30                       385                              310.0
# 31                        82                               47.0
# 32                        22                               12.0
# 33                       671                                NaN
# 34                        69                               19.0
# 35                       406                               70.0
# 36                      5568                             1255.0
#
#     District Hospitals  Hospitals  HospitalBeds   Population
# 0                    3         34          1246     380581.0
# 1                   20       1666         60799   49386799.0
# 2                   15        199          2320    1383727.0
# 3                   33       1220         19115   31205576.0
# 4                   43       2146         17796  104099452.0
# 5                    4         47          3756    1055450.0
# 6                   32       1023         14354   25545198.0
# 7                    1         13           568     343709.0
# 8                    2          8           298     243247.0
# 9                   47        615         20572   16787941.0
# 10                   3         40          2666    1458545.0
# 11                  37       2236         41129   60439692.0
# 12                  28        683         13841   25351462.0
# 13                  15        671          8706    6864602.0
# 14                  29        818         11342   12267013.0
# 15                  23        558          7404   32988134.0
# 16                  42       2943         56333   59248274.0
# 17                  53       1297         39511   33406061.0
# 18                   1         10           250      64473.0
# 19                  51       1867         38140   72626809.0
# 20                  70       3239         68998  112374333.0
# 21                   9        114          2562    2855794.0
# 22                  13        180          4585    2966889.0
# 23                   9         87          2312    1097206.0
# 24                  11        166          1944    1978502.0
# 25                  35       1799         16497   41974218.0
# 26                   4         53          4462    1247953.0
# 27                  28        742         13527   27743338.0
# 28                  33       3139         51844   68548437.0
# 29                   4         32          1145     610577.0
# 30                  32       2581         72616   72147030.0
# 31                  15        932         17358   35193978.0
# 32                   9        157          4895    3673917.0
# 33                 174       4122         58310  199812341.0
# 34                  20        383          6660   10086292.0
# 35                  55       1905         51163   91276115.0
# 36                1003      37725        739024          NaN

# %%
hospcen.iloc[36,-1]=hospcen.iloc[:-1,-1].sum()

# %%
hospcen
# Out:
#                        State/UT  Number of Primary Health Centers  \
# 0   andaman and nicobar islands                                27
# 1                andhra pradesh                              1417
# 2             arunachal pradesh                               122
# 3                         assam                              1007
# 4                         bihar                              2007
# 5                    chandigarh                                40
# 6                  chhattisgarh                               813
# 7        dadra and nagar haveli                                 9
# 8                 daman and diu                                 4
# 9                         delhi                               534
# 10                          goa                                31
# 11                      gujarat                              1770
# 12                      haryana                               500
# 13             himachal pradesh                               516
# 14            jammu and kashmir                               702
# 15                    jharkhand                               343
# 16                    karnataka                              2547
# 17                       kerala                               933
# 18                  lakshadweep                                 4
# 19               madhya pradesh                              1420
# 20                  maharashtra                              2638
# 21                      manipur                                87
# 22                    meghalaya                               138
# 23                      mizoram                                65
# 24                     nagaland                               134
# 25                       orissa                              1360
# 26                  pondicherry                                40
# 27                       punjab                               521
# 28                    rajasthan                              2463
# 29                       sikkim                                25
# 30                   tamil nadu                              1854
# 31                    telangana                               788
# 32                      tripura                               114
# 33                uttar pradesh                              3277
# 34                  uttarakhand                               275
# 35                  west bengal                              1374
# 36                    all india                             29899
#
#     Community Health Centers  Sub-District/Divisional Hospitals  \
# 0                          4                                NaN
# 1                        198                               31.0
# 2                         62                                NaN
# 3                        166                               14.0
# 4                         63                               33.0
# 5                          2                                1.0
# 6                        166                               12.0
# 7                          2                                1.0
# 8                          2                                NaN
# 9                         25                                9.0
# 10                         4                                2.0
# 11                       385                               44.0
# 12                       131                               24.0
# 13                        79                               61.0
# 14                        87                                NaN
# 15                       179                               13.0
# 16                       207                              147.0
# 17                       229                               82.0
# 18                         3                                2.0
# 19                       324                               72.0
# 20                       430                              101.0
# 21                        17                                1.0
# 22                        29                                NaN
# 23                        10                                3.0
# 24                        21                                NaN
# 25                       377                               27.0
# 26                         4                                5.0
# 27                       146                               47.0
# 28                       579                               64.0
# 29                         2                                1.0
# 30                       385                              310.0
# 31                        82                               47.0
# 32                        22                               12.0
# 33                       671                                NaN
# 34                        69                               19.0
# 35                       406                               70.0
# 36                      5568                             1255.0
#
#     District Hospitals  Hospitals  HospitalBeds    Population
# 0                    3         34          1246  3.805810e+05
# 1                   20       1666         60799  4.938680e+07
# 2                   15        199          2320  1.383727e+06
# 3                   33       1220         19115  3.120558e+07
# 4                   43       2146         17796  1.040995e+08
# 5                    4         47          3756  1.055450e+06
# 6                   32       1023         14354  2.554520e+07
# 7                    1         13           568  3.437090e+05
# 8                    2          8           298  2.432470e+05
# 9                   47        615         20572  1.678794e+07
# 10                   3         40          2666  1.458545e+06
# 11                  37       2236         41129  6.043969e+07
# 12                  28        683         13841  2.535146e+07
# 13                  15        671          8706  6.864602e+06
# 14                  29        818         11342  1.226701e+07
# 15                  23        558          7404  3.298813e+07
# 16                  42       2943         56333  5.924827e+07
# 17                  53       1297         39511  3.340606e+07
# 18                   1         10           250  6.447300e+04
# 19                  51       1867         38140  7.262681e+07
# 20                  70       3239         68998  1.123743e+08
# 21                   9        114          2562  2.855794e+06
# 22                  13        180          4585  2.966889e+06
# 23                   9         87          2312  1.097206e+06
# 24                  11        166          1944  1.978502e+06
# 25                  35       1799         16497  4.197422e+07
# 26                   4         53          4462  1.247953e+06
# 27                  28        742         13527  2.774334e+07
# 28                  33       3139         51844  6.854844e+07
# 29                   4         32          1145  6.105770e+05
# 30                  32       2581         72616  7.214703e+07
# 31                  15        932         17358  3.519398e+07
# 32                   9        157          4895  3.673917e+06
# 33                 174       4122         58310  1.998123e+08
# 34                  20        383          6660  1.008629e+07
# 35                  55       1905         51163  9.127612e+07
# 36                1003      37725        739024  1.208734e+09

# %%
hospcen['bedsper10000']=(hospcen['HospitalBeds']/hospcen['Population'])*10000

# %%
hospcen.sort_values('bedsper10000').head(3)
# Out:
#          State/UT  Number of Primary Health Centers  Community Health Centers  \
# 4           bihar                              2007                        63
# 15      jharkhand                               343                       179
# 33  uttar pradesh                              3277                       671
#
#     Sub-District/Divisional Hospitals  District Hospitals  Hospitals  \
# 4                                33.0                  43       2146
# 15                               13.0                  23        558
# 33                                NaN                 174       4122
#
#     HospitalBeds   Population  bedsper1000  bedsper10000
# 4          17796  104099452.0     1.709519      1.709519
# 15          7404   32988134.0     2.244443      2.244443
# 33         58310  199812341.0     2.918238      2.918238

# %%
plt.figure(figsize=(25,20))
plt.bar(height=hospcen['bedsper10000'], x=hospcen['State/UT'],)
plt.xticks(rotation=90)
plt.show()

# %%
#question 13

# %%
govhos1=pd.read_csv('government_hospitals.csv')

# %%
govhos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   States/UTs       37 non-null     object
#  1   Rural hospitals  38 non-null     object
#  2   Unnamed: 2       38 non-null     object
#  3   Urban hospitals  38 non-null     object
#  4   Unnamed: 4       38 non-null     object
#  5   As on            36 non-null     object
# dtypes: object(6)
# memory usage: 1.9+ KB

# %%
govhospital=govhos1.copy()

# %%
govhospital.head(2)
# Out:
#        States/UTs Rural hospitals Unnamed: 2 Urban hospitals Unnamed: 4  \
# 0             NaN             No.       Beds             No.       Beds
# 1  Andhra Pradesh             193       6480              65      16658
#
#         As on
# 0         NaN
# 1  01.01.2017

# %%
govhospital.rename(columns={'States/UTs':'State/UT','Rural hospitals':'Rural_Government_Hospitals','Unnamed: 2':'Rural_Government_Beds',
                           'Urban hospitals':'Urban_Government_Hospitals','Unnamed: 4':'Urban_Government_Beds','As on':'Last_Updated'},inplace=True)

# %%
govhospital.drop(0,axis=0,inplace=True)

# %%
govhospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   State/UT                    37 non-null     object
#  1   Rural_Government_Hospitals  38 non-null     object
#  2   Rural_Government_Beds       38 non-null     object
#  3   Urban_Government_Hospitals  38 non-null     object
#  4   Urban_Government_Beds       38 non-null     object
#  5   Last_Updated                36 non-null     object
# dtypes: object(6)
# memory usage: 1.9+ KB

# %%
w=govhospital['Last_Updated'].copy()

# %%
#question14

# %%
govhospital['Last_Updated']=pd.to_datetime(w)
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3924229756.py:1: UserWarning: Parsing '31.12.2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   govhospital['Last_Updated']=pd.to_datetime(w)
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3924229756.py:1: UserWarning: Parsing '31.12.2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   govhospital['Last_Updated']=pd.to_datetime(w)
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3924229756.py:1: UserWarning: Parsing '30.12.2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   govhospital['Last_Updated']=pd.to_datetime(w)
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3924229756.py:1: UserWarning: Parsing '31.12.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   govhospital['Last_Updated']=pd.to_datetime(w)

# %%
govhospital
# Out:
#                      State/UT Rural_Government_Hospitals  \
# 0                         NaN                        No.
# 1              Andhra Pradesh                        193
# 2          Arunachal Pradesh*                        208
# 3                       Assam                       1176
# 4                       Bihar                        930
# 5                Chhattisgarh                        169
# 6                        Goa*                         17
# 7                     Gujarat                        364
# 8                    Haryana*                        609
# 9           Himachal Pradesh*                        705
# 10            Jammu & Kashmir                         56
# 11                  Jharkhand                        519
# 12                 Karnataka*                       2471
# 13                     Kerala                        981
# 14             Madhya Pradesh                        334
# 15                Maharashtra                        273
# 16                    Manipur                         23
# 17                 Meghalaya*                        143
# 18                   Mizoram*                         56
# 19                   Nagaland                         21
# 20                    Odisha*                       1655
# 21                    Punjab*                        510
# 22                  Rajasthan                        602
# 23                    Sikkim*                         24
# 24                Tamil Nadu*                        692
# 25                 Telangana*                        802
# 26                   Tripura*                         99
# 27             Uttar Pradesh*                       4442
# 28                Uttarakhand                        410
# 29                West Bengal                       1272
# 30  Andaman & Nicobar Islands                         27
# 31                 Chandigarh                          0
# 32      Dadra & Nagar Haveli*                         10
# 33                Daman & Diu                          5
# 34                      Delhi                          0
# 35                Lakshadweep                          9
# 36                 Puducherry                          3
# 37                      INDIA                      19810
#
#    Rural_Government_Beds Urban_Government_Hospitals Urban_Government_Beds  \
# 0                   Beds                        No.                  Beds
# 1                   6480                         65                 16658
# 2                   2136                         10                   268
# 3                  10944                         50                  6198
# 4                   6083                        103                  5936
# 5                   5070                         45                  4342
# 6                   1405                         25                  1608
# 7                  11715                        122                 20565
# 8                   6690                         59                  4550
# 9                   5665                         96                  6734
# 10                  7234                         76                  4417
# 11                  5842                         36                  4942
# 12                 21072                        374                 49093
# 13                 16865                        299                 21139
# 14                 10020                        117                 18819
# 15                 12398                        438                 39048
# 16                   730                          7                   697
# 17                  1970                         14                  2487
# 18                   604                         34                  1393
# 19                   630                         15                  1250
# 20                  6339                        149                 12180
# 21                  5805                        172                 12128
# 22                 21088                        150                 10760
# 23                   260                          9                  1300
# 24                 40179                        525                 37353
# 25                  7668                         61                 13315
# 26                  1140                         56                  3277
# 27                 39104                        193                 37156
# 28                  3284                         50                  5228
# 29                 19684                        294                 58882
# 30                   575                          3                   500
# 31                     0                          4                   778
# 32                   273                          1                   316
# 33                   240                          0                     0
# 34                     0                        109                 24383
# 35                   300                          0                     0
# 36                    96                         11                  3473
# 37                279588                       3772                431173
#
#    Last_Updated
# 0           NaT
# 1    2017-01-01
# 2    2017-12-31
# 3    2017-12-31
# 4    2016-12-31
# 5    2016-01-01
# 6    2017-12-31
# 7    2016-12-31
# 8    2016-12-31
# 9    2017-12-31
# 10   2016-12-30
# 11   2015-12-31
# 12   2017-12-31
# 13   2017-01-01
# 14   2016-01-01
# 15   2015-12-31
# 16   2014-01-01
# 17   2017-12-31
# 18   2017-12-31
# 19   2015-12-31
# 20   2017-12-31
# 21   2017-12-31
# 22   2016-12-31
# 23   2017-12-31
# 24   2017-12-31
# 25   2017-12-31
# 26   2017-12-31
# 27   2017-12-31
# 28   2015-12-31
# 29   2015-01-01
# 30   2016-12-31
# 31   2016-12-31
# 32   2017-12-31
# 33   2015-12-31
# 34   2015-01-01
# 35   2016-01-01
# 36   2016-01-01
# 37          NaT

# %%
govhospital=filter_State_func(govhospital)
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_11024\3746379972.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   my_df["State/UT"]=my_df["State/UT"].str.replace("*","")

# %%
govhospital.drop(0,axis=0,inplace=True)

# %%
govhospital.to_csv('Clean/government_hospital.csv')

# %%
govhospital
# Out:
#                        State/UT Rural_Government_Hospitals  \
# 1                andhra pradesh                        193
# 2             arunachal pradesh                        208
# 3                         assam                       1176
# 4                         bihar                        930
# 5                  chhattisgarh                        169
# 6                           goa                         17
# 7                       gujarat                        364
# 8                       haryana                        609
# 9              himachal pradesh                        705
# 10            jammu and kashmir                         56
# 11                    jharkhand                        519
# 12                    karnataka                       2471
# 13                       kerala                        981
# 14               madhya pradesh                        334
# 15                  maharashtra                        273
# 16                      manipur                         23
# 17                    meghalaya                        143
# 18                      mizoram                         56
# 19                     nagaland                         21
# 20                       orissa                       1655
# 21                       punjab                        510
# 22                    rajasthan                        602
# 23                       sikkim                         24
# 24                   tamil nadu                        692
# 25                    telangana                        802
# 26                      tripura                         99
# 27                uttar pradesh                       4442
# 28                  uttarakhand                        410
# 29                  west bengal                       1272
# 30  andaman and nicobar islands                         27
# 31                   chandigarh                          0
# 32       dadra and nagar haveli                         10
# 33                daman and diu                          5
# 34                        delhi                          0
# 35                  lakshadweep                          9
# 36                  pondicherry                          3
# 37                        india                      19810
#
#    Rural_Government_Beds Urban_Government_Hospitals Urban_Government_Beds  \
# 1                   6480                         65                 16658
# 2                   2136                         10                   268
# 3                  10944                         50                  6198
# 4                   6083                        103                  5936
# 5                   5070                         45                  4342
# 6                   1405                         25                  1608
# 7                  11715                        122                 20565
# 8                   6690                         59                  4550
# 9                   5665                         96                  6734
# 10                  7234                         76                  4417
# 11                  5842                         36                  4942
# 12                 21072                        374                 49093
# 13                 16865                        299                 21139
# 14                 10020                        117                 18819
# 15                 12398                        438                 39048
# 16                   730                          7                   697
# 17                  1970                         14                  2487
# 18                   604                         34                  1393
# 19                   630                         15                  1250
# 20                  6339                        149                 12180
# 21                  5805                        172                 12128
# 22                 21088                        150                 10760
# 23                   260                          9                  1300
# 24                 40179                        525                 37353
# 25                  7668                         61                 13315
# 26                  1140                         56                  3277
# 27                 39104                        193                 37156
# 28                  3284                         50                  5228
# 29                 19684                        294                 58882
# 30                   575                          3                   500
# 31                     0                          4                   778
# 32                   273                          1                   316
# 33                   240                          0                     0
# 34                     0                        109                 24383
# 35                   300                          0                     0
# 36                    96                         11                  3473
# 37                279588                       3772                431173
#
#    Last_Updated
# 1    2017-01-01
# 2    2017-12-31
# 3    2017-12-31
# 4    2016-12-31
# 5    2016-01-01
# 6    2017-12-31
# 7    2016-12-31
# 8    2016-12-31
# 9    2017-12-31
# 10   2016-12-30
# 11   2015-12-31
# 12   2017-12-31
# 13   2017-01-01
# 14   2016-01-01
# 15   2015-12-31
# 16   2014-01-01
# 17   2017-12-31
# 18   2017-12-31
# 19   2015-12-31
# 20   2017-12-31
# 21   2017-12-31
# 22   2016-12-31
# 23   2017-12-31
# 24   2017-12-31
# 25   2017-12-31
# 26   2017-12-31
# 27   2017-12-31
# 28   2015-12-31
# 29   2015-01-01
# 30   2016-12-31
# 31   2016-12-31
# 32   2017-12-31
# 33   2015-12-31
# 34   2015-01-01
# 35   2016-01-01
# 36   2016-01-01
# 37          NaT

# %%
# ['Rural_Government_Hospitals','Rural_Government_Beds','Urban_Government_Hospitals','Urban_Government_Beds']
govhospital['Rural_Government_Hospitals']=govhospital['Rural_Government_Hospitals'].astype('float64',)
govhospital['Rural_Government_Beds']=govhospital['Rural_Government_Beds'].astype('float64')
govhospital['Urban_Government_Hospitals']=govhospital['Urban_Government_Hospitals'].astype('float64')
govhospital['Urban_Government_Beds']=govhospital['Urban_Government_Beds'].astype('float64')

# %%
#question15

# %%
hospcen.sort_values('bedsper1000').iloc[:3,:].sort_values('Hospitals').iloc[0]
# Out:
# State/UT                              jharkhand
# Number of Primary Health Centers            343
# Community Health Centers                    179
# Sub-District/Divisional Hospitals          13.0
# District Hospitals                           23
# Hospitals                                   558
# HospitalBeds                               7404
# Population                           32988134.0
# bedsper1000                            2.244443
# Name: 15, dtype: object

# %%
govhospital.drop('Total_Goverment_Beds', axis=1,inplace=True)

# %%
govhospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 1 to 37
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   State/UT                    37 non-null     object
#  1   Rural_Government_Hospitals  37 non-null     float64
#  2   Rural_Government_Beds       37 non-null     float64
#  3   Urban_Government_Hospitals  37 non-null     float64
#  4   Urban_Government_Beds       37 non-null     float64
#  5   Last_Updated                36 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 1.9+ KB

# %%
#Question 16

# %%
hospcen.drop('bedsper1000', axis=1, inplace=True)

# %%
hospcen['bedsper1000']=(hospcen['HospitalBeds']/hospcen['Population'])*1000

# %%
hospcen['required']=(3*hospcen['Population'])/1000-hospcen['HospitalBeds']

# %%
notrequired=hospcen[hospcen['required']<0].index

# %%
hospcen.loc[notrequired,'required']=0

# %%
hospcen=hospcen.iloc[0:36,:]

# %%
hospcen
# Out:
#                        State/UT  Number of Primary Health Centers  \
# 0   andaman and nicobar islands                                27
# 1                andhra pradesh                              1417
# 2             arunachal pradesh                               122
# 3                         assam                              1007
# 4                         bihar                              2007
# 5                    chandigarh                                40
# 6                  chhattisgarh                               813
# 7        dadra and nagar haveli                                 9
# 8                 daman and diu                                 4
# 9                         delhi                               534
# 10                          goa                                31
# 11                      gujarat                              1770
# 12                      haryana                               500
# 13             himachal pradesh                               516
# 14            jammu and kashmir                               702
# 15                    jharkhand                               343
# 16                    karnataka                              2547
# 17                       kerala                               933
# 18                  lakshadweep                                 4
# 19               madhya pradesh                              1420
# 20                  maharashtra                              2638
# 21                      manipur                                87
# 22                    meghalaya                               138
# 23                      mizoram                                65
# 24                     nagaland                               134
# 25                       orissa                              1360
# 26                  pondicherry                                40
# 27                       punjab                               521
# 28                    rajasthan                              2463
# 29                       sikkim                                25
# 30                   tamil nadu                              1854
# 31                    telangana                               788
# 32                      tripura                               114
# 33                uttar pradesh                              3277
# 34                  uttarakhand                               275
# 35                  west bengal                              1374
#
#     Community Health Centers  Sub-District/Divisional Hospitals  \
# 0                          4                                NaN
# 1                        198                               31.0
# 2                         62                                NaN
# 3                        166                               14.0
# 4                         63                               33.0
# 5                          2                                1.0
# 6                        166                               12.0
# 7                          2                                1.0
# 8                          2                                NaN
# 9                         25                                9.0
# 10                         4                                2.0
# 11                       385                               44.0
# 12                       131                               24.0
# 13                        79                               61.0
# 14                        87                                NaN
# 15                       179                               13.0
# 16                       207                              147.0
# 17                       229                               82.0
# 18                         3                                2.0
# 19                       324                               72.0
# 20                       430                              101.0
# 21                        17                                1.0
# 22                        29                                NaN
# 23                        10                                3.0
# 24                        21                                NaN
# 25                       377                               27.0
# 26                         4                                5.0
# 27                       146                               47.0
# 28                       579                               64.0
# 29                         2                                1.0
# 30                       385                              310.0
# 31                        82                               47.0
# 32                        22                               12.0
# 33                       671                                NaN
# 34                        69                               19.0
# 35                       406                               70.0
#
#     District Hospitals  Hospitals  HospitalBeds   Population  bedsper10000  \
# 0                    3         34          1246     380581.0     32.739417
# 1                   20       1666         60799   49386799.0     12.310780
# 2                   15        199          2320    1383727.0     16.766313
# 3                   33       1220         19115   31205576.0      6.125508
# 4                   43       2146         17796  104099452.0      1.709519
# 5                    4         47          3756    1055450.0     35.586717
# 6                   32       1023         14354   25545198.0      5.619060
# 7                    1         13           568     343709.0     16.525607
# 8                    2          8           298     243247.0     12.250922
# 9                   47        615         20572   16787941.0     12.254034
# 10                   3         40          2666    1458545.0     18.278490
# 11                  37       2236         41129   60439692.0      6.804965
# 12                  28        683         13841   25351462.0      5.459646
# 13                  15        671          8706    6864602.0     12.682454
# 14                  29        818         11342   12267013.0      9.245935
# 15                  23        558          7404   32988134.0      2.244443
# 16                  42       2943         56333   59248274.0      9.507956
# 17                  53       1297         39511   33406061.0     11.827494
# 18                   1         10           250      64473.0     38.775922
# 19                  51       1867         38140   72626809.0      5.251504
# 20                  70       3239         68998  112374333.0      6.140014
# 21                   9        114          2562    2855794.0      8.971235
# 22                  13        180          4585    2966889.0     15.453898
# 23                   9         87          2312    1097206.0     21.071704
# 24                  11        166          1944    1978502.0      9.825616
# 25                  35       1799         16497   41974218.0      3.930270
# 26                   4         53          4462    1247953.0     35.754552
# 27                  28        742         13527   27743338.0      4.875765
# 28                  33       3139         51844   68548437.0      7.563119
# 29                   4         32          1145     610577.0     18.752754
# 30                  32       2581         72616   72147030.0     10.065002
# 31                  15        932         17358   35193978.0      4.932094
# 32                   9        157          4895    3673917.0     13.323654
# 33                 174       4122         58310  199812341.0      2.918238
# 34                  20        383          6660   10086292.0      6.603021
# 35                  55       1905         51163   91276115.0      5.605300
#
#     bedsper1000    required  require
# 0      3.273942       0.000      0.0
# 1      1.231078   87361.397      NaN
# 2      1.676631    1831.181      NaN
# 3      0.612551   74501.728      NaN
# 4      0.170952  294502.356      NaN
# 5      3.558672       0.000      0.0
# 6      0.561906   62281.594      NaN
# 7      1.652561     463.127      NaN
# 8      1.225092     431.741      NaN
# 9      1.225403   29791.823      NaN
# 10     1.827849    1709.635      NaN
# 11     0.680497  140190.076      NaN
# 12     0.545965   62213.386      NaN
# 13     1.268245   11887.806      NaN
# 14     0.924593   25459.039      NaN
# 15     0.224444   91560.402      NaN
# 16     0.950796  121411.822      NaN
# 17     1.182749   60707.183      NaN
# 18     3.877592       0.000      0.0
# 19     0.525150  179740.427      NaN
# 20     0.614001  268124.999      NaN
# 21     0.897124    6005.382      NaN
# 22     1.545390    4315.667      NaN
# 23     2.107170     979.618      NaN
# 24     0.982562    3991.506      NaN
# 25     0.393027  109425.654      NaN
# 26     3.575455       0.000      0.0
# 27     0.487577   69703.014      NaN
# 28     0.756312  153801.311      NaN
# 29     1.875275     686.731      NaN
# 30     1.006500  143825.090      NaN
# 31     0.493209   88223.934      NaN
# 32     1.332365    6126.751      NaN
# 33     0.291824  541127.023      NaN
# 34     0.660302   23598.876      NaN
# 35     0.560530  222665.345      NaN

# %%
plt.figure(figsize=(25,20))
plt.bar(x=hospcen['State/UT'],height=hospcen['HospitalBeds'], color='red')
plt.bar(x=hospcen['State/UT'], height=hospcen['required'], color='blue')
plt.xticks(rotation=90)
plt.show()
